# %%
import pandas as pd
import nltk

# %%
path = "public_data_labeled.csv"
file = pd.read_csv(path)
file.shape
# Out:
# (24783, 2)

# %%
file.head()
# Out:
#    label                                               Text
# 0      0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %% [markdown]
# # tokenization

# %%
sentences = []
for sentence in file.Text:
    sentences.extend(nltk.sent_tokenize(sentence))
sentences
# Out:
# ['!!!',
#  "RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house.",
#  '&amp; as a man you should always take the trash out...',
#  '!!!!!',
#  'RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!',
#  '!',
#  '!!!!!!!',
#  'RT @UrKindOfBrand Dawg!!!!',
#  'RT @80sbaby4life: You ever fuck a bitch and she start to cry?',
#  'You be confused as shit',
#  '!!!!!!!!!',
#  'RT @C_G_Anderson: @viva_based she look like a tranny',
#  '!!!!!!!!!!!!!',
#  'RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;',
#  '!!!!!!!!!!!!!!!!!!',
#  '"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes!',
#  '&#128514;&#128514;&#128514;"',
#  '!!!!!!',
#  '"@__BrighterDays: I can not just sit up and HATE on another bitch ..',
#  'I got too much shit going on!"',
#  '!!!',
#  "!&#8220;@selfiequeenbri: cause I'm tired of you big bitches coming for us skinny girls!",
#  '!&#8221;',
#  '" &amp; you might not get ya bitch back &amp; thats that "',
#  '" @rhythmixx_ :hobbies include: fighting Mariam"\n\nbitch',
#  '" Keeks is a bitch she curves everyone " lol I walked into a conversation like this.',
#  'Smh',
#  '" Murda Gang bitch its Gang Land "',
#  '" So hoes that smoke are losers ? "',
#  'yea ... go on IG',
#  '" bad bitches is the only thing that i like "',
#  '" bitch get up off me "',
#  '" bitch nigga miss me with it "',
#  '" bitch plz whatever "',
#  '" bitch who do you love "',
#  '" bitches get cut off everyday B "',
#  '" black bottle &amp; a bad bitch "',
#  '" broke bitch cant tell me nothing "',
#  '" cancel that bitch like Nino "',
#  '" cant you see these hoes wont change "',
#  '" fuck no that bitch dont even suck dick " &#128514;&#128514;&#128514; the Kermit videos bout to fuck IG up',
#  '" got ya bitch tip toeing on my hardwood floors " &#128514; http://t.co/cOU2WQ5L4q',
#  '" her pussy lips like Heaven doors " &#128524;',
#  '" hoe what its hitting for "',
#  '" i met that pussy on Ocean Dr .',
#  'i gave that pussy a pill " &#128524;',
#  '" i need a trippy bitch who fuck on Hennessy "',
#  '" i spend my money how i want bitch its my business "',
#  '" i txt my old bitch my new bitch pussy wetter "',
#  '" i\'d say im back to the old me but my old bitches would get excited " &#128524;',
#  '" if you aint bout that Murder Game pussy nigga shut up "',
#  '" if you\'re toes ain\'t done you pussy stinks "',
#  '" im done with bitter bitches its a wrap for that .',
#  'if you a angry bird theres a app for that "',
#  '" is that ya bitch "',
#  '" it aint nothing to cut a bitch off "',
#  '" jus meet son now he ya mane ass bitches " #Shots',
#  '" lames crying over hoes thats tears of a clown "',
#  '" like Snoop said in 94 we dont love these hoes "',
#  '" momma said no pussy cats inside my doghouse "',
#  '" most hated but the hoes favorite " #2MW #SevenOne # http://t.co/BMdSVMc3rC',
#  '" nice girls bad, make me get naughty.',
#  'Bad yello hoe, real nice body.',
#  'Down south chick, like em real thick" http://t.co/bzRDl3kF7U',
#  '" pimps up pimps up hoes down " Future voice',
#  '" post a picture of that pussy get 200 likes "',
#  '" pussy is a powerful drug " &#128517; #HappyHumpDay http://t.co/R8jsymiB5b',
#  '" quick piece of pussy call it a drive by "',
#  '" running round here like some brand new pussy thats bout to get fucked "',
#  '" these bitches even worst they\'ll send them guys for you "',
#  '" these hoes like niggas that spend money not talk bout it "',
#  '" we dont trust these niggas all these bitches "',
#  '" yall niggas b cuffing hoes cause yall aint never have bitches "',
#  '" you dodge a bullet " &#128517; &#8220;@DaRealKha: "All da bitches I cut off pregnant or bound to be ....thank God &#128591;"&#8221;',
#  '" young Pill Chamberlain these bitches love my music "',
#  '"&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;@VandalSavage_: Teanna Trump probably cleaner than most of these twitter hoes but........."',
#  '"&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;@DaHomieFuzz: Gay niggas couldn\'t wait to act like bitches tonight"',
#  '"&#128514;&#128514;&#128514;@The_Paradox: And ima steal his cat n replace it with a pitbull &#128514;&#128514;&#128514;&#128514; RT @80sbaby4life: @The_Paradox He a bitch you should do it"',
#  '"&amp; he\'s gone always be a hoe"',
#  '"...Son of a bitch took my Tic Tacs."',
#  'I like this movie.',
#  '"..All I wanna do is get money and fuck model bitches!"',
#  '- Russell Simmons',
#  '"@2015seniorprobs: I probably wouldn&#8217;t mind school as much if we didn&#8217;t have to deal with bitch ass teachers".',
#  'Retweet',
#  '"@A7XDemery: I\'m a fucking fag they said"',
#  '"@ARIZZLEINDACUT: Females think dating a pussy is cute now?',
#  'http://t.co/VxBJg26Gsz" how does doing this stuff make him a pussy?',
#  '"@Addicted2Guys: -SimplyAddictedToGuys http://t.co/1jL4hi8ZMF" woof woof hot scally lad',
#  '"@AdoreBellaaa: Have ya ever asked your bitch for other bitches - kanye voice" Yes',
#  '"@AdoreZoey: How u gone bring ur side bitch to a game where You know Ya gf friends at ?!',
#  '&#128553;&#128553;&#128553;&#128553;" I SWEAR!!!!',
#  '!',
#  '"@AllAboutManFeet: http://t.co/3gzUpfuMev" woof woof and hot soles',
#  '"@Allyhaaaaa: Lemmie eat a Oreo &amp; do these dishes."',
#  'One oreo?',
#  'Lol',
#  '"@Almightywayne__: @JetsAndASwisher @Gook____ bitch fuck u http://t.co/pXmGA68NC1" maybe you\'ll get better.',
#  'Just http://t.co/TPreVwfq0S',
#  '"@Almightywayne__: Fuck Red Malone man bitch ass niggah" could you please use complete sentences?',
#  '"@ArizonasFinest6: Why the eggplant emoji doe?',
#  '"y he say she looked like scream lmao',
#  '"@AutoWorId: Hennessey Venom GT &#128584; http://t.co/i8eGMnKaJ9" that\'s one sexy bitch',
#  '"@BOSSBYTCHH: Him seh me pussy wetter then a shower curtain....#ahmesehwetness"&lt;lmao!',
#  '!',
#  '"@BRO_HEN314: #Eaglesnation and every #Eagles need to see that pic I just posted because that bitch just said the most racist shit"',
#  '"@BVSEDCHINK: Yo fuck skateboarding, all y\'all some wood pushing faggots man, ball is life http://t.co/VBCzP6HMT7"\n@AmJemieBenn',
#  '"@BabyAnimalPics: baby monkey bathtime http://t.co/7KPWAdLF0R"\nAwwwwe!',
#  'This is soooo ADORABLE!',
#  '"@BaylaaGottaBody: &#128514;&#128514;&#128514;&#128514; I ain\'t shit ."',
#  'Damn Skippy lol',
#  '"@BeEasyJrizzy: u ever kill a ant on the sidewalk and think damn what if that nigga was on his way to get some pussy"No bs must b &gt;30%chance',
#  '"@BeenBasedB: @_KudaBrazyy http://t.co/LuUBGL9Y5u" 0 rings 0 mvps 0 bitches lol',
#  '"@BeenFLYnSolo: ppl talk bad about the ghetto/hood ... but as a kid growing up, a nigga had funnnnnnn !"',
#  '"@BestProAdvice: The facts on tattoos...tattoo http://t.co/ZwnbhpDZ8e" he\'s a pussy with not tattooing them nipples',
#  '"@Bill215_: &#128175;&#128175;&#128175; RT @nel_ayden Bitches be wanting to act like niggas so bad &#128553;&#128553;&#128553; that shit aint cuteeeee" but niggas act like bitches..',
#  '"@BitchJones92: Get worshiping bitch!',
#  'http://t.co/R37CejCjou" woof woof',
#  '"@BlackChiquitita: Wow.',
#  "RT @thatmanpalmer I'm lost.",
#  'Are those buttcheek piercings?',
#  'http://t.co/yn6guyOUQ6" yeah she\'s a hoe',
#  '"@BlackNerdJade: Ok, sis."',
#  "She'd rather be a broke bitch?",
#  "*shrugs* she'll have to tell me how it works for her",
#  '"@Blackman38Tide: @WhaleLookyHere @HowdyDowdy11 queer" gaywad',
#  '"@BrokenPiecesmsc: @ItsNotAdam faggot read my tweets after dat k" it wasn\'t even funny lol',
#  '"@BrosConfessions: This bitch was so ungrateful http://t.co/06e77bGwbx" fr ..... LULWHORE',
#  '"@CASHandBOOBIES: I been kidnapped yo bitch"',
#  '"@CB_Baby24: @white_thunduh alsarabsss" hes a beaner smh you can tell hes a mexican',
#  '"@CCobey: @AydanMcCoy happy birthday nigs" Thanks yo',
#  '"@CHlLDHOODRUINER: when ur teacher tells u that u have homework https://t.co/RKk5vawIj1" this bitch need to go!!',
#  '!',
#  '"@CaelanG15: "@22EdHam: @CaelanG15 that nigga was eating that hoe lol" Hell Yea lol john Paul" nigga said john paul.. http://t.co/OSIpBKPr9h',
#  '"@CanIFuckOrNah: What would y\'all lil ugly bald headed bitches do if they stop making make-up &amp; weave?"',
#  '"@CarelessOne92: Leafs better win this damn game so I can go riot and shit #EarlyChristmas" you better start looting my nig',
#  '"@CauseWereGuys: Going back to school sucks more dick than the hoes who attend it."',
#  '"@CauseWereGuys: On my way to fuck yo bitch http://t.co/j906T5zE2R" me as a 9 year old',
#  '"@CeleyNichole: @white_thunduh how come you never bring me food" i dont have a car retard',
#  '"@ChadMFVerbeck: If Richnow doesn\'t show up with hella tinder hoes Im not his friend anymore" chill I brought like like 8 prople',
#  '"@ChandlerParsons: How bout them Cowboys!!!!"',
#  'Shutup pussy',
#  '"@ClicquotSuave: LMAOOOOOOOOOOO this nigga @Krillz_Nuh_Care http://t.co/AAnpSUjmYI" &lt;bitch want likes for some depressing shit..foh',
#  '"@Coley_Cee: @lil_aerii girl you know I was spitting that G shit to you &amp; you was going lbvs"bitch plz',
#  '"@Coley_Cee: Let me make a couple tweets off cuzzo page, so I won\'t get in twitter jail.',
#  '"lmao bitch don\'t trick me again',
#  '"@ComedyPosts: Harlem shake is just an excuse to go full retard for 30 seconds."',
#  '"@ComedyTruth: amen miley &#128591; http://t.co/P2Kb2tfyxr"okay, but she don\'t need to act like a hoe just bc she\'s "emotionally damaged" foh',
#  '"@CoryBandz: having one loyal female is wayyyyy better than having hoes , idc &#128175;"',
#  '"@Crhedrys: Pussy licking pussy.... meow meow #StopWhitePeople2014 &#128049; https://t.co/KeegDCjS5K&#8221;""""\n\n&#128533;',
#  '"@DBAB_Holloway: Check out our 12th man.',
#  '#CowboysNation" even with all those faggot ny fans in the stands',
#  '"@DGotBricks: What happen to them vixen ent bitches" they got ran and threw to the side like a foothill bitch',
#  '"@DaeDaviDavie: @white_thunduh im the bitch okay nudes pat &#128554;&#128527;&#128056;" wow',
#  '"@DevilGrimz: @VigxRArts you\'re fucking gay, blacklisted hoe" Holding out for #TehGodClan anyway http://t.co/xUCcwoetmn',
#  '"@DiamondLoudKush: The fuck be wrong with these bitches?"',
#  'Nobody knows',
#  '"@Dietrich1892: Yall shut up:p" make me bitch',
#  '"@DionaIrish: I hate a "I\'m pregnant" type of bitch."',
#  '"@DoYou_Q: Got bitches in the DM but I don\'t ever read\'em" which is y your top 3',
#  '"@DomWorldPeace: Baseball season for the win.',
#  '#Yankees" This is where the love started',
#  '"@Dommoneek: Little stupid as bitch I don\'t fuck with yoooooouuuu.."',
#  '"@DreadheadAri: she really asked me that dead ass serious tho, all i could say was "bitch wheet" LOL',
#  '"@DunderbaIl: I\'m an early bird and I\'m a night owl, so I\'m wise and have worms."',
#  '"@EdgarPixar: Overdosing on heavy drugs doesn\'t sound bad tonight."',
#  'I do that pussy shit every day.',
#  '"@El_Grillo1: Pit Bulls Photographed As Lovely Fairy Tale Creatures http://t.co/Q0Sm89oOLh&#8221;\n\nThey *are* fairy tale creatures.',
#  '"@Ferocious_Ghost: @1stName_Bravo Aw."',
#  '...fag, don\'t tweet "aw" to me lol',
#  '"@FloKid88: As long as the Lakers trash from now on, I could careless.',
#  'And that\'s real.".',
#  'CC: @BENBALLER hahaha',
#  '"@Frosstyy_: @h0rheyd I didn\'t say anything tho" kiss me then faggot',
#  '"@FunnyPicsDepot: this the "I play soccer, cheat on girls, and wear khaki coloured cargos" haircut http://t.co/ZUai7qWBIR" &#128514; yup',
#  '"@G27Status: I could go for a fat ass bitch on my lap" same',
#  '"@GEDMelle: 17 missed calls!!!!',
#  '&#128544;&#128545;"Das yo P.O bitch twitter finna be screamn #FreeMoneyMelle',
#  '"@GTM_Al: Ya side bitch gotta know it\'s rules to this shit..anybody ask you my cousin from jersey thinkin bout moving" lmmfao &#128514;&#128514;&#128514;&#128514;',
#  '"@GagaTom1: &#8220;@MaleFoot: 3 | Amo los pies http://t.co/4QE1hDkK8i&#8221;" fuck yeah',
#  '"@GirlThatsVonte: These hoes be thinking Meat won\'t slap they ass &#128564;&#128075;" ainna bruh',
#  '"@GirlThatsVonte: Yall bitches wit no edges be doing the most talking &#128553;&#128564;&#9995;"&#128514;&#128514;&#128514;',
#  '"@GirlThatsVonte: Yall still going trick or treating this year or nah?',
#  '"hell yeah ima be da sweet tooth bandit steal bitches bags n shit',
#  '"@Girllssues: I wanna have sex with my mom fuck her right in that pussy where I came from" damn you got hacked like fuck',
#  '"@Gizzy_Jones94: If she kiss u with her eyes open watch that bitch!',
#  '"lmfao',
#  '"@Goofstroop: You a woulda coulda shoulda ass hoe &#128563;&#128586;"',
#  '"@Gotti_LTF: Happy Bday Bitch Ass Nigga @JetsAndASwisher"preciate that bitch roll up!',
#  '"@HBMostDope: @1Jayee @PipinHoes used to send that bitch up"',
#  '"@HBMostDope: Ugly bitches be like I\'m my own WCW duh bitch you ain\'t nobody elses&#128514;&#128514;"',
#  '"@HaloTGMG: @1stName_Bravo nigga you know we hacky sack hoes."',
#  '...nah, I throw no look passes lmao',
#  '"@HeartlessFuck: Glad I\'m getting outta Atlanta.',
#  'Nothing but a bunch of niggas in &amp; outta jail &amp; dumb bitches with mad kids fuckin em."',
#  '"@HermosaAlma: This isn\'t ghetto.....it\'s smart https://t.co/MPAzQ3Jswf" I\'m doing this idc',
#  '"@HiImJoriB: I would wife a hoe only cuz we wouldn\'t care that we cheating in each other."',
#  '...why force the relationship in the first place?',
#  '"@HornyFacts: Being single isn\'t an excuse to be a hoe."',
#  '@TheOneMiss_Luu',
#  '"@HoskinsTy96: White boy power bitch" black power bitch',
#  '"@Hudgens_11: Lets get drunk, get blowed, spit shit spark blunts &amp; fuck hoes!"',
#  'Bro white dudes have no chill.',
#  '"@IScoutGirls: @verbally_abrupt bitch where u been" Around the world and back.',
#  'Where you been?',
#  '"@ItsYahBoiRay: @anelylove if I don\'t get my dick sucked at yo party by a bad bitch I\'m fr gone set it off &#128514;&#128514;&#128514;&#128514;" *by @anelylove *',
#  '"@Itsyesie: #oomf is soooo cute.',
#  'But he probably has hoes on him a lot."',
#  '"@JAYten9: In every cartoon theirs alway a @_nuffsaid15 saving these hoes lmao.',
#  'http://t.co/9uKD8wtZ6x" lmao damn captain SaveAHoe',
#  '"@JReebo: Who wants to get there nose in these bad bois then #scally #chav #sockfetish #stinking http://t.co/FeQxgN0W6I" hot sox and legs',
#  '"@JamesyNBA: I wish I was a bitch like my brother keezy &#128530;" ooooow I bet you do',
#  '"@JasminePore: If you dressed up as a cat for Halloween you are basic."',
#  '...or a pussy',
#  '"@Jewelxo: Can pornhub just get a gaming stream feature so these dumb bitches can gtfo" @Pornhub get on it Katie&lt;3',
#  '"@JoeBudden: stop being scared to choke her during sex u bitch ass niggas.',
#  'She&#8217;ll like it.".',
#  'Says the guy who hits women out of bed.',
#  'FOH',
#  '"@Johnny55Perez: @white_thunduh ha well iguess I make them hoes loyal bro" theyll never be loyal that y they hoes my nig',
#  '"@KazAtta: @1TAKEHOV Oh man.. "its 5 am, you off a molly, ho where the fuck ya seed at??""',
#  '#fixed',
#  '"@KelsieBelsi: You\'re not a man if you refer to every girl as a bitch"',
#  '"@KeyshawnSwag: Lmfao this cat started beating the shit out of me" my nigga finally got some pussy?!?',
#  'MY NIGGA!!',
#  '!',
#  '"@KeyshawnSwag: Peel up peel up bring it back up rewind back where I\'m from they move Shaq from the line" ooooow who tf said that trash!!',
#  '?',
#  '"@KingCuh: @16stanleys io io alu record ho vine sai pe hahahaha" lol anywaaaaaays..... haha',
#  '"@KingHendo95: @VonDreaam naw it\'s my old tape.',
#  'new cover .',
#  'my upcoming mixtape is #KingOfTheHill" Yeah I\'m waiting on that hoe Mayne!',
#  '"@KingTeej_: Ol dirty foot ass bitches.." this was too funny to me.',
#  '"@King_Shawn_6: @white_thunduh that\'s where I get my yellow flags for being amazing &#128079;&#128524;" HELL YEAH NIGGY',
#  '"@KissMySmilee: Don\'t got time for bitches to be actin iffy."',
#  '"@KnightfanNeal #UCFPINKPARTY come on stay alive knights nation!!!!"',
#  'This is still the early bird special.',
#  '#ComeAtMeUT',
#  '"@KyraNadiya_: These hoes ain\'t loyal ; no they ain\'t http://t.co/h1UBsVbkGl"\n\nSmfh &amp; wonder why nobody decent wants them',
#  '"@LCisTJ: Bruh, you studs keep thinking I\'m soft as hell.',
#  'Ask ya girl how many times she screamed she was my bitch.',
#  'Oh okay.',
#  'STFU."',
#  'BYE HOE!',
#  '"@LODYCASH: dry pussy bitches always blame it on the condom&#128514;"&#128079;&#128514;&#128079;&#128514;',
#  '"@LUNAraps: shut yo bitch ass up!',
#  'https://t.co/IemN1u0gm5" &#128557;&#128514;',
#  '"@LaFlareGodJosh: Gucci Mane in jail and dropping mixtapes every month and you hoes can\'t even text back"',
#  '"@Latrobemark: You love these hoes more then money wats wrong these niggas"',
#  '"@LeBronVuitton: A loyal bitch from the burbs without daddy issues is like finding a holographic Mewtwo."',
#  '...sounding like me over there lol',
#  '"@LiLFridayHOE: Easy cum, easy hoe" That\'s a fact !',
#  '"@LifeAsBros: Charlie Sheen is too real http://t.co/gGGdK3kOV7" major fucking respect for Charlie Sheen.',
#  '"@Lightskingawdd: Wish I had a bae &#128533;"\n\nYou got all the hoes tho',
#  '"@Lil_Mike_12: Fuck twerking bitch can you cook ?"',
#  '"@Linniekravitz: @WesGodLaFlare bitch wtf" http://t.co/DaSmycxODB',
#  '"@Lipe_the_Great: &#8220;@h0rheyd: "@Lipe_the_Great: Shut up zoe" fight me pussy&#8221; for zoe?',
#  'I\'m good, man."',
#  "You are good ma'am.",
#  'Move along now',
#  '"@LolaaIsDope: Lmao fucking snake bitches" @ em',
#  '"@Loveable_Aizah: Big booty hoes everywhere sheesh &#128525;" damn &#127807;&#128064;&#127807;',
#  '"@MLBNetwork: Stay tuned to @MLBNetwork for an update on the report that @Yankees 1B @teixeiramark25 will be out 8-10 weeks" @dliming35 #bum',
#  '"@M_Rad: &#8220;@DezDLT: "I play soccer, cheat on girls, and wear khaki coloured cargos" haircut http://t.co/tYCIhD6PkW&#8221; yes lmfao"@soccerboy_04',
#  '"@MadFlyentist: Oregon chokes every year get off the field trash ass program" RFT',
#  '"@MannyDiesel: Def not cowboy lol RT @ArtofFloyd: Terrell Owens was the best Eagle &amp; Cowboy ever" ..dude cried like a bitch on tv, over Romo',
#  '"@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPLE https://t.co/RNvD2nLCDR" This is why there\'s black people and niggers',
#  '"@Master11_: @20ToLife_ @GabrielaStarr How could u do this to me bitch" potent',
#  '"@MaxMayo77: http://t.co/3Jk4kR44X3" a pissed lad past out.',
#  'I would lick his dirty soles while he slept.',
#  '"@MaxMayo77: http://t.co/PrrskknqRv" love frat boy w/ soft long soles',
#  '"@MaxMayo77: http://t.co/XpSC3makgJ" sexy lad with hot soles and arches.',
#  '"@MegamindNick: @white_thunduh nah fam I gotta cheat with the hoes" depends on the female i feel',
#  '"@Mesha_nojas: @_Vontethekidd &#128079;&#128079;&#128079;&#128079;&#128588;" I got hicks lol',
#  '"@Migsmichelen: This new twitter is confusing the shit out of me."',
#  'Go back to south america bitch',
#  '"@Miikito_x3: Toto means ass or vagina?',
#  '"I think pussy cause toto santi is like nasty pussy',
#  '"@MikelaHenry: but what if he actually does choose the ugly bitch over you?',
#  '&#58381;"Her ass must be fat!',
#  '"@MileyCyrus: bitch couldn\'t kill my vibe if ya tried.',
#  '&#127752;&#127752;&#127752;" dis why i love miley :*',
#  '"@Montrell_: I\'m tired of bitches saying I look mean.. &#128530;" nigga you big af, wear tight shirts, and grim everybody.',
#  '"@MotherJones: 10 birds your grandkids may never see, thanks to climate change http://t.co/XqmXHkAsWt http://t.co/RbITeGRnhm" #Climate',
#  '"@MvckFadden: "Stay beautiful you bitch""',
#  '"@NICKIMINAJ: #WutKinda\n\nr purple.',
#  'Ceeeleee"man this gurl was jus playin on the "stupid hoe " track.',
#  'But in still shitted on sum gurls',
#  '"@NastyCopper: Money getting taller and bitches getting blurry"',
#  '"@NewsomeJade: I ain\'t never seen a bitch so obsessed with they nigga&#128514;" I\'m obsessed with mine &#128529;',
#  '"@Nicholas_ted33: Kobe stay talking trash.',
#  'But let\'s not forget http://t.co/VH4tnEkvTP" @J_Austin12 I meant to do this one.',
#  'Smh.',
#  '"@NoChillPaz: "At least I\'m not a nigger" http://t.co/RGJa7CfoiT"\n\nLmfao',
#  '"@No_FAKINGG: People always asking me what I\'m mixed with."',
#  'She a bad asian bitch lol',
#  '"@NotoriousBM95: @_WhitePonyJr_ Ariza is a snake and a coward" but at least he isn\'t a cripple like your hero Roach lmaoo',
#  '"@OSAY_it_aint_so: &#8220;@IgnoreAllLaws: Fosters home for imaginary trash&#8221; WHOA CHILL"\n\nthat show was everything tf',
#  '"@OfficialReplay: I am lowkey tired."',
#  '...if you tired, be quiet and go to sleep hoe!',
#  '"@PRAYINGFORHEAD: &#8220;@macklemroe: Stop bringing weird niggers into my mentions!',
#  '@PRAYINGFORHEAD&#8221; http://t.co/cussDJesRK"',
#  '"@PRETTyBOSs_BRAt: We don\'t love these hoes &#128080;&#128581;"',
#  '"@PatrickQuelo: If yo girl cant have homeboys you a ol weak bitch ass nigga!"',
#  '"@Patsfanjoe32: @d_palomino52 I think worst advice I gave you was " don\'t be a pussy and speed up" lol"',
#  '"@PoemsPorn: Quote this tweet with your favorite animal.',
#  '"pussy',
#  '"@Poetic_Success: I hate when strippers tell you they\'re "dancers".',
#  "Hoe, ballet dancers don't pop their pussy to Beethoven.",
#  'You a STRIPPER!"',
#  '"@Poffalicious: Andrewbryant: Poff has double vision after 2 beers\nPoff: ...',
#  'Double pussy &#128526;" smh',
#  '"@Poobie_: When bitches TWERK on the computer....\n\nME: "In ya &#128089;, in ya damn &#128089;&#8252;&#65039;""',
#  '"@ProdsJewel_: &#8220;@sreadthepeace: &#8220;@yungmindless: @PeacePunkPrince Prince, THIS is art.',
#  'http://t.co/EPHRWxMBHr&#8221; nobody takin his bitch!',
#  '"@QUAN1T0: 61% of welfare/government aid is claimed by white people.',
#  'So y\'all black slander is trash now."',
#  '"@QUAN1T0: These bitches don\'t care they just play that role."',
#  '"@Queen_Kaaat: It took a while for you to find me, but I was hiding In the lime tree."',
#  '@Iemonaids dis bitch in da wrong tree bro.',
#  '"@RTNBA: Drakes new shoes that will be released by Nike/Jordan....',
#  'Yes, there\'s glitter on the shoes http://t.co/QCtPLxHEXM" ....dudes a fag',
#  '"@RachieSoul: @DizzleOfficial inna di ghetto!!!"',
#  'You alone lmaoo',
#  '"@RamBoutIt: &#8220;@Master11_: @20ToLife_ @RamBoutIt hoes Austin&#8221; teach us Austin.',
#  '"I teach u how to get curved?',
#  "That's all I know",
#  '"@ReachtheeCLIMAX: bitches can\'t cook but know how to suck dick .." s/o to the ones that can do both!',
#  '"@RenegadeMo: Fat hoes get chose" lol',
#  '"@RiahSM: #hoesaintloyal" well they\'re hoes,no one expects them to be loyal',
#  '"@RishaaWilliams: @TRESHON_SCROOGE @_Nevertrustt ol bitch ass" http://t.co/AmcOinY0wG',
#  '"@RnadJorell: Bruh im tired of niggas retweetin Miley Cyrus naked that bitch aint no types of bad" lmaooo',
#  '"@SacTownProdigy: Just because tony romo at the mavs game dont mean he still not a bitch lmao.. Fuk them cowgirls" lol bitch fuck you',
#  '"@SamJLayman : Holy shit, Freddie Highmore was in Charlie and the Chocolate Factory"\nMe: *rolls on the floor, laughing*',
#  '"@Samirahusic_: "I don\'t want to have sex with my gf because I feel like I\'m using her.." - anonymous" Whata faggot',
#  '"@SexualGxfs: @ One of your followers with this &#128525;&#128553; http://t.co/F1TJl9xnCT" @ somebody, bitch if you don\'t',
#  '"@Shaa_Jenkins: If ya bitch always bitching clearly she care!"',
#  'Or just an annoying Bitch!',
#  '"@ShanTaughtHer: These catfish hoes thinkin they slick..',
#  'But niggas catching on &#128524;"',
#  '"@SheWentToJordan: Can\'t worry about a bitch that ain\'t worried bout me" #real',
#  '"@ShowArrive: Side hoes are for insecure niggas that can\'t handle a real one."',
#  '"@Shun_stokes: &#128514;&#128514;&#128514;&#128514;RT @bluprint_4: Lmao!',
#  'This bitch come scooting in the tent like she about to fuck some shit up!"',
#  '&#128557;&#128557;&#128557;',
#  '"@Shun_stokes: My cousin said he share hoes with his brothers.',
#  'He said sharing is caring and he love his brothers &#128514;"',
#  '"@SlimGirl_Probz: i\'m hungry but ionn wanna spend my money on food&#128530;"Broke hoe problems &#128514;&#128514;&#128514;&#128128;',
#  '"@SmeegBaby: Dese hoes be LYIN to all of us nigga"',
#  '"@SnakecharmsDump: http://t.co/4b427dQZCV" oh yeah fuck that bitch',
#  '"@SportsCenter: Eli Manning just threw his NFL-leading 27th interception of the season."',
#  'Lmao trash',
#  '"@SportsCenter: USC senior RB Anthony Brown calls head coach Steve Sarkisian a racist and quits team.',
#  '&#187; http://t.co/JOOsdSubIR" he\'s a bitch',
#  '"@StellaTex: Guess what?',
#  'I also have zero time for your mansplaining!',
#  'Adios!"',
#  'Stfu pussy',
#  '"@Stephenwildboy: Chilling &#128069;&#8482; http://t.co/mik3iPNle6" sexy scally lad',
#  '"@Strap__: I ain\'t sharing no bitch if you mines you mines &#128175;"',
#  '"@SukMySweetness: money only impress the simple broke bitches"',
#  '"@Sylvieamx: #Pisces will never be anybody\'s bitch, they don\'t let people control or change them."',
#  'Rigghhht',
#  '"@TEE_JONEZ: @16stanleys @KingCuh tuku ho idk blah blah blah" &#128514;&#128514;&#128514;',
#  '"@TEE_JONEZ: @KingCuh @16stanleys I\'m not mad cuh hahaha" suure.. tuku ho ita!',
#  '&#128514;&#128514;',
#  '"@TayKnosBest: These hoes is crazy"',
#  '"@Taylorr_Babee: You ain\'t ever gonna be a slice bitch."',
#  'Kevin hart.',
#  '(:',
#  '"@ThatniggaTroy: Oomf so fuckin fine tho &#128553; dam" @ her, don\'t be no bitch.',
#  '"@TheGamerKingKev: I wonder if the girl that gave head to 24 boys for a drink in magaluf has twitter" she probly sends nudes for fags',
#  '"@TheNewSAT: #NewSATQuestions\nYeah bitch, yeah bitch, call me _______:\na.)',
#  'Maybe\nb.)',
#  'Steve-O\nc.) Later\nd.) Jesse Pinkman"\n@machinegunkelly',
#  '"@TheNymphoTweets: Hickies in between her thighs right by her pussy &gt;&gt;&gt;" Its only right',
#  '"@TheOneMiss_Luu: Would you still love me when I\'m no longer young and beautiful?"',
#  'No.',
#  'Ugly monkey ass.',
#  '"@TheRealRickyB21: @JetsAndASwisher @Gook____ y\'all come through the front.',
#  '"bitch I ain\'t coming',
#  '"@TheRealRickyB21: @JetsAndASwisher faggot bitch" http://t.co/2HyyAbk4eH',
#  '"@The_Realist_Sam: @Madrid2_ yea, I\'m on my iPad.',
#  "I don't work this Friday.",
#  'Let\'s ball this faggot up @TropicalBlanket"i work 2-5',
#  '"@Theo17100: http://t.co/BYj1HOyhmG" this scally lad would get it',
#  '"@TheoMaxximus: #GerrysHalloweenParty http://t.co/3ycrSrnjHc" Halloween was yesterday stupid nigger',
#  '"@TheoMaxximus: Chrus still supahot tho" *walks up to teacher with test, drops test in that bitch fohead* http://t.co/nb5VgdssgI',
#  '"@Thornton25: &#8220;@KantKeepAhBYTCH: I love eating pussy lol I never get full lol&#8221; I can eat that shit forever lol" and ever.',
#  '"@Tmacc_GFG: &#8220;@VoiceOfDStreetz: "@Tmacc_GFG: &#8220;@tizzimarie: No slushes &#128549;&#8221;hoes nasty anyway fam"&#128564;&#8221;them hoes taste like meds"&#127815;&#127815;&#127868;',
#  '"@Tmacc_GFG: &#8220;@tizzimarie: No slushes &#128549;&#8221;hoes nasty anyway fam"&#128564;',
#  '"@Tmacc_GFG: BOBBY BITCH-by @BobbyShmurdaGS9 be getting me live as fuck" hell yea i play that hoe before my workout',
#  '"@TreLeKidd: Yo bitch is Gucci Mane RT @JabariTheGreat : My bitch a stoner &#128175;&#128175; http://t.co/lt9LIJjpg9"&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;',
#  '"@TweetGameLazy: I can ride your bitch with no handle bars"',
#  '"@TyJonCuffee: And if you ain\'t a hoe get up out my traphoussseeeee"',
#  '"@UberFacts: 15 sad TV character deaths we\'re still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man',
#  '"@UnHoly_Jack: These harbor bitches are all "Party Bus hoes"" Lol all?',
#  '"@Vbomb20: @Woodchuck20 pussy" love it',
#  '"@VeronikaHumbert: Ultraviolence video, its coming you little bitch!',
#  '#MTVHottest Lana Del Rey http://t.co/533fLbvWqh" \n\nbitchy promo',
#  '"@VineForTheByrd: On my way to fuck your bitch https://t.co/4lMTFNL2iy"\n\nLMFAO KITTYCOPTER',
#  '"@WBUR: A smuggler explains how he helped fighters along the "Jihadi Highway": http://t.co/UX4anxeAwd"',
#  '"@WBeezy_: "@QuaTheGreat: Aww their avis look so cute together &#128145; http://t.co/9lPorCb8w0" &#128128;&#128128;&#128128;" do I gotta get Ike avi on this bitch ?',
#  '"@WBeezy_: "@Run_DRC: Its simple, dont be a hoe=dont worry about being exposed &#128540;" fight me"why ?',
#  '"@WannabeKanye: whys this bitch boosting herself http://t.co/uOd2f5WtKV"\n\nHer size isn\'t exactly the most healthy tho',
#  '"@WitHaPrettyface: @_1nonlykeisha bet not be no bitches!',
#  '&#128514;&#128080;&#128299;&#128299;&#128298;" &#128514;&#128514; Kim bye!!',
#  '!',
#  '"@X_XPDOTJDOT: Damn near gotta protect my tweets.. stalkers being annoying" you got that dope dick.',
#  'Drive these bitches loco',
#  '"@XoJennyGirl: I\'m making marack my girlfriend ."',
#  '@marackaf aye b you pullin hoes just like o taught you',
#  '"@XoXo__Angiee: Bruno fag boy" you love me.',
#  '"@YEHits_Von: &#8220;@Run_DRC: I must be a bitch&#8221; you are &#128514;&#128514;&#128514; sike naw" This why we always beefing &#128514;',
#  '"@Yankees: Down 6-1, #Yankees look to rally in the bottom of the 9th."',
#  '#RALLYCAP',
#  '"@YoungRicooo: &#8220;@WexicanAfro702: Don\'t take advantage of a nice person&#8221;@ hoes"@ everyjuan',
#  '"@YoungRicooo: Happy birthday bitch nigga @WexicanAfro702" Thanks pal',
#  '"@YoungRicooo: Sad knowing that most hoes won\'t fuck with you bc you ain\'t got stacks."',
#  'wait till friday',
#  '"@YunGMiGo: @Shane_A1 cinco shit harder fucc nigga"yee but you fucc wit rich homie cuz dats ya homeboy fucc nicca',
#  '"@ZoeBarton3: @h0rheyd ewww I said THAT last Sunday..as in the last Sunday I was there.',
#  'Read it again nigs"&#128563;&#128563;&#128563;&#128563;&#128563;',
#  '"@_BaDa_Bing: I only punch real niggas in the face cause a pussy Nigga is gonna punch me right back" Strong Mush or Shake..',
#  '"@_BeeDontCare My pussy still fresh" &lt;----- something stank girls say.',
#  '"@_GeeWillikers_: Ass slapping is one the greatest things.',
#  'Haha.',
#  '&#128527;" I slapped a girl on the ass.',
#  '.',
#  'She got mad I aint get pussy for a week',
#  '"@_TommyCollins: @WeAreRichnow @buffalobills yeah Texans are so much better you fucking retard" I see that you\'re mad about this.',
#  '"@__MALIBUbarbie: Nd wtf is up with dark bitches with blonde..',
#  'PLEASE HAVE SEVERAL SEATS HOE!"',
#  '..looking like black&amp;milds out here',
#  '"@__Sugga: There\'s a lane some bitches need to stay in &#128526;" the left n get right the fuck outta our face &#128557;&#128129;&#128536;',
#  '"@__sneakyb: I hate when boys deny that they have bitches &#128080;&#128553;" smh',
#  '"@__taradise__: Ya nigs out there still saying y\'all don\'t eat butt?!"',
#  'WITH A STRAIGHT FACE!',
#  '"@__youreWelcome: Im a boss ass bitch" ...that needs to sit in a corner',
#  '"@_iwantfranny: He\'s a hoe , I can\'t"',
#  '"@_prettyflvck0: Me And Paul Thinkin Bout Gettin Rentals For Da Weekend &#128665;&#128168;&#128168;"oooh shit bitches betta stay out da streets',
#  '"@_rapdreams: bitches hold they nigga down when he get locked up... but if a nigga go to college or the military it\'s a different story.',
#  '&#128564;"',
#  '"@_simplycaitlin: why do my friends hate me" because you a ratchet hoe..',
#  '"@adriwadrri: No love for these fuck niggas" hoes*',
#  '"@airmaxlad1: Hot meat http://t.co/BRz8Imk5vK" sexy as fuck scally lad.',
#  'I would love to meet him and his trainers.',
#  '"@airmaxlad1: Sniff http://t.co/FHHbBRMYBN" perved up scally lad.',
#  'fuck yeah.',
#  '"@alejandra_p13: These bitches love Sosa"',
#  '"@alexissixela__: &#8220;@white_thunduh: I legit watched it for about 30 or 40 seconds &#128529;&#8221;SO DID I WTF" prob cause were retarded smh',
#  '"@allisonnamaya_: What should I name my cat, ideas?"',
#  'Mr pussy',
#  '"@altosteel115: http://t.co/tM28mh5XG2" woof woof.',
#  'Sexy thug boy scally.',
#  '"@ambitiousBree: @_1nonlykeisha u see the damn phone ringing?',
#  '&#128547;&#128530;&#128542;" when you married bitches makes demands!!!!',
#  "You haven't called me",
#  '"@analicialouise: Tevin is my favorite sophomore I think he\'s so funny" Hes really not.',
#  'Lmaoo hes a little hoe',
#  '"@angelenagoley: 10 sex positions http://t.co/nt3PABMWsm http://t.co/JmHZ8Sczf0"naw this what u call fucking the soul outta bitch &#128557;',
#  '"@ashlingwilde: @ItsNotAdam is bored supposed to be cute, you faggot?"',
#  'Sometimes',
#  '"@ayyee_ceee_: One mans trash &#128686; is another mans treasure &#127942;"',
#  '"@babineaux_: I don\'t got no type.',
#  'Bad bitches is the only thing I like" *Iongotnotype',
#  '"@bigbootybishopp: @white_thunduh lassen cc , the coach wants me" i feel it youll get more my nig no doubt',
#  '"@bleedingtrap: god teeth , gold chain\nwhite bitches , cocaine"',
#  '"@cheetahBluntz_: Its me hoe, its me hoe&#128129;" shhhhh',
#  '"@chieflottahoes: In D.C., we call them rollers, in Chiraq we call them thots."',
#  'All across America they have been known as a hoe.',
#  '"@clayton_jenn99: I\'m gonna miss that bitch of a bus driver..."no you won\'t.',
#  "Don't lie",
#  '"@coltforty2Gone: hate when bitches try and put you in the friendzone.',
#  'bitch I\'m tryin to score put me in the endzone &#128293;&#128293;&#128293;" ON.',
#  'MY.',
#  'SOUL!',
#  '"@complex_uk: Ashley Young has tried to deny that bird s*** landed in his mouth ---&gt; http://t.co/mlr5eWgonK https://t.co/AvCHFj7reM" hahaha',
#  '"@datFullerkid: @TreVaughnLG yall both gimped up??"',
#  "Ain't tht a bitch huh lol",
#  '"@deepthroatMike: "@Boys_South: Take me for a ride &#128525;&#128139; http://t.co/H5mAtjYfGA"#redneck" woof woof',
#  '"@demi_eggleton: oh my god I love Victoria Mitchell" all my bitches love me',
#  '"@djsliime: That long distance shit wack I knew the bitch was cheating"- uh oh',
#  '"@fIirting: HE\'S DOING IT RIGHT &#128525;&#128120;&#128158; http://t.co/JZKkiVUVjC" no bitches smh',
#  '"@fatboyswagg347: they BAN dat pussy for life &amp; he gotta pay 2.5 millon dollar fine"',
#  '"@fuckcamoclark: Roses are red and violets are blue and niggers are black, you know that\'s true."',
#  '@dylan72892',
#  '"@g0rillaz0e: Sitting on my window sill, window open, bird tries to fly in.',
#  'Smacked it.',
#  '#ProtectTheAnimals" @peta',
#  '"@glowstruck: But a nigga gon be a nigga, be a nigga."',
#  'You sound fuckin retarded',
#  '"@greggutfeld: a video an entire media will likely mock.',
#  'http://t.co/XFr1cRXWSm" i am such a crybaby',
#  '"@gurl_Im_Angie: @ItsKiaraaaa @WestYourMajesty I\'m not even shy stfu" kikis mom: Hi angelique \nAngelique: Smiles *Dips cracker in soup*',
#  '"@haitian__goLd: Tim Tebow got cut from every team he was on in the NFL and he already got more hoes than me in Starkville.',
#  'Smh."',
#  '&#128514;&#128514;&#128514;&#128514;',
#  '"@hazelebaby: Karma is a bitch #Damn #GodProtectsHisAngels &#128588;"\n\n*sips tea*',
#  '"@hornyjhb: Fuckin hot gym pussy http://t.co/ZVYmcXQuTA" fuck yeah',
#  '"@hxhassan: Jihadi patron Hajjaj al-Ajmi is arrested at Kuwait airport https://t.co/ZmloKfWDQl"',
#  '"@iAMPickUpLines: You can call me Fireman cause I turn the hoes on."',
#  '"@iCrawley: I could never have a bby by a lil dick Thts y I got a abortion by the last bitch"- oh My God',
#  '"@iDntWearCondoms: Watch women try to argue with me like they have a dick and actually fucked some pussy before" I hate when bitches do that',
#  '"@iLGDaily: And smoke weed in public, fuck cops man, do what you wanna do, they don\'t own you, run if they come" are you retarded?',
#  '"@iTrapWatermelon: tweety bird tho &#128514;&#128514;&#128514;&#128514;https://t.co/JbnoNM3N1P"',
#  '"@irlfatty: my pussy sweet like watermelon http://t.co/SKlPh3TtoG"\n\nThotermelon',
#  '"@itscoleharmon_: When twitter rappers dm me their trash links http://t.co/35nMR4AUQg"',
#  '"@jSadass: loud bitches annoy me"',
#  '"@jacaxeltlu: Eventually every bitch turns into that hoe."',
#  '# Truuu',
#  '"@jaimescudi_: "@Tonybthrz_: "@jaimescudi_: I swear if oomf try talking to me tomorrow.." @" @BarackObama" pussy',
#  '"@jama_jam: You bitches be pretending to be TF crazy.." You ain\'t never lied...',
#  '"@jasmyncyniquee: @white_thunduh k bye hoe" um bye ..',
#  '"@jayswaggkillah: Jackies a retard #blondeproblems" At least I can make a grilled cheese!',
#  '"@jboii2: ima keep on giving these pussy ass niggas ah reason to hate !"',
#  '"@jethromass: Photo: http://t.co/CxRs5BVhPw" he is in sole heaven',
#  '"@jgabsss: Stacey Dash won &#128166; http://t.co/PDLG46rjOL" baddest bitch evaaaa',
#  '"@juicyyyjayyyy: Side bitch Sunday &#128514;&#128514;&#128514;" &#128514;&#128514;&#128514;',
#  '"@k_eazy26: Facts what baldheaded bitch made this shit.',
#  '&#128074;&#128074;&#128555;&#128530; http://t.co/fDYojpT9Xg"\n\nLmao &#128553;&#128514;',
#  '"@kayreneeee_: Fuck wit us and then we tweakin hoe" shmurda!',
#  '"@kazooook: We actin like it\'s the 7th day @WesGodLaFlare http://t.co/s9gMtEvpaT"\n&#128123;spook',
#  '"@kikiSTFU: I\'ll break that lil bitch neck and won\'t even feel sorry about it" Savage',
#  '"@leikant: This is so fucking hot!!',
#  '#scally #sneakersex #sockfetish #sniff #trainersex http://t.co/TubivxbxcO" love me some kinky scallies',
#  '"@likemicah: Y\'all dumb ass niggas be so pressed to have hoes.',
#  'Y\'all weak as fuck as fuck" ...weed over hoes, oreos too.',
#  '"@lildurk_: I can turn yo bitch into a eaterrrrrrrrr"',
#  '"@lildurk_: I don\'t trust dese hoes Nikki told 51st where I stay at all my fans screen shot ASAP" we finna come to Chiraq and shoot sumn',
#  '"@marackaf: &#8220;@white_thunduh: Aye yall ima tryout for the bowling team frfr&#8221; tryouts passed tho" no theres two more retard',
#  '"@maybe6789: Now u got what u want bitch !',
#  'Enjoy it http://t.co/gLQzwtGMj9" now this is a crazy party I would love to attend.',
#  '"@metroadlib: colored contacts in your eyes?',
#  'blinders on mine.',
#  'cause i can\'t see you at all."',
#  'Lmao',
#  '"@michelle_westt: Facts "@POONsoaker: Only the dudes with hoes say they don\'t got hoes&#8221;" @J_Austin12',
#  '"@midyWIDEY_: I\'m rea start smacking bitches period !"',
#  'Bluffin at its best',
#  '"@molssyo: Lifes a bitch, and then you die \nThats why we get high, cause you neva know when you\'re gonna go" my sister is perfect (:',
#  '"@molssyo: One of us is on drugs, and its me but you\'re still wrong &#128514; @currieburry" hahahahahahah im a bitch sometimes (:',
#  '"@morgandaylee: I\'m feeling pretty fuckin ghetto" Smh',
#  '"@nohands_24: "@20ToLife_: "@nohands_24: "@DejaaLeeann_: @B_Coleman2 swears I\'m #1 man" easily" easily" behind Austin" nip?',
#  '"@obey_jrock__: This is a true ride or die bitch &#128175; http://t.co/bkwHX83fkW" what the fuck hahahahah',
#  '"@oldpicsarchive: H.G.Wells and Charlie Chaplin http://t.co/sTiDDHK3WT" #History #Photography',
#  '"@ortiz_jaylene: All I see is Bruno\'s bitch ass on my twitter now.',
#  'wtf" Bruno\'s all that she sees (Drake voice)',
#  '"@ozzie_garza: @white_thunduh I\'m about to cool faggot chill" tf is cool nigga',
#  '"@ozzie_garza: @white_thunduh I\'m so sure bitch" frfr tf',
#  '"@poppunksucks: Twitter is not a source of news broadcast you fucking retards" it is when nbc, abc, cnn, Fox, etc are all keeping quiet.',
#  '"@queendulaaa: Got a couple bitches saying they know me But I&#8217;ma let the money talk for me &#128526;&#128076;" AND I\'M LIKE... #WWYD',
#  '"@realFORTES: Grudges are for weirdos"and bitches',
#  '"@rhythmixx_: I told Mariam to but cigarettes for her birthday"\n\nYou also called me trash rn',
#  '"@riananewman: @22EdHam brownies tonight" what kind?!?',
#  '!',
#  '"@roLLYuP23: No text back?',
#  'I don\'t give a fuck, I\'ll text another bitch" damn someone is hurt lol',
#  '"@ronald_iongi: Ummmmmm okay http://t.co/4BVLsci5K5" you got hoes from left to right &#128514;&#128514; do yah thang!',
#  '"@royalswagg_: using y=mx+b to find the slope of that ass"',
#  '"@rugbysocklad: Fit lads!',
#  'Nice gear!',
#  'http://t.co/ThnXX1lC1M" these scally lads n trainers would get it',
#  '"@rugbysocklad: Hell yeah bro!',
#  'http://t.co/9yIb45UD6c" fuck yeah sexy scally lad in hot gear',
#  '"@rugbysocklad: Helping out a mate!!',
#  'http://t.co/eMNAdO1QOj" I love scally play.',
#  'Fuck yeah',
#  '"@rugbysocklad: Lads being Lads!',
#  'http://t.co/f3UJcYJ4OF" fuck yeah.',
#  'I love scally lad action.',
#  'Hot trainers too.',
#  '"@savage_twotone: Next year bitches is gonna be like you gotta promise you won\'t expose me &#128514;&#128514;&#128557;"',
#  '"@scallynikelad: &#8220;@sleazytwinks: So hot!!',
#  'RT @opcinjen: Lick it, bitch http://t.co/JLoUkqDcOM&#8221;" fuck yeah.',
#  'Eat that trainer u dirty fucker',
#  '"@sierrabernia: &#8220;@T2G_CincoKilby: Y\'all think celebrity pussy different from the locals?',
#  '&#128514;&#8221; yeah Meghan goods is"',
#  '"@sleepy_yongguk: "I saw an ajumma walk out in the beginning saying, \'Wow, this is so trash that I can\'t even listen to it..\'" &#128514;" lmaoo',
#  '"@sniffsockslad: Need these sox http://t.co/xydb1RchXh" fuck yeah.',
#  'I love a kinky scally lad w/ rank sox and sneaks',
#  '"@snoleezey801: I don\'t ever expose females like that.. That\'s childish.." bitch nigga shiiii.....',
#  '"@socass_: "@00sexilexi00: @socass_ yasss"\n\n*trys new things with bestfriend*"\n\n*bitch who do you love*',
#  '"@socass_: Dude remember this wop video?',
#  '@00sexilexi00 http://t.co/P3HEuBOQBu" OMG WHERE DID YOU FIND THAT',
#  '"@soxandjox: Thick raw fuck http://t.co/g8RvUHCeBN" Damn his man pussy is getting a workout.',
#  '"@soxdawg: RAWR!!',
#  'RT @skinrubberboi: "My" sexy French scally.',
#  'I love him!',
#  '#frenchscally http://t.co/5idQ3R5Akz" sexy scally woof woof',
#  '"@splurgb_: Nothin in life is free..',
#  'Some of you bitches need to write that on ya panties"&#128557;&#128514;',
#  '"@stephencdo: @currieburry if one of you bitches want some of my burrito u can catch me at potosino" huh?',
#  'Haha',
#  '"@talibanshawtyy: Niggas whole hoes out here cuz" Couldn\'t had said it better..&#128588;',
#  '"@theaveragerocks: Hardcore way to eat Mac and cheese\n1.',
#  'Boil water \n2.',
#  'Snort cheese powder\n3.',
#  'Drink boiling water \n4.',
#  'Fuck bitches"',
#  '"@thebravebird: #YoureNotMyType if my fade is perpetually fresher than yours."',
#  "That's a real ass bitch rite there",
#  '"@thejudyann: annoying bitch that I love http://t.co/8oxlQvQBrC" JUDYANN\'S SO PRETTY!!!!',
#  '!',
#  '"@thotmouths: http://t.co/aQKGOrAUxx"\n\nLmao bitch got on some huggies',
#  '"@trestiffer: Hi bitch \nNo bitch\nBye bitch" http://t.co/RbcRXMRtQP',
#  '"@trutherbot: does he look like a bitch?"',
#  '@el_capacitor',
#  '"@whoiscoreyking: Chase money &#128176; not &#128581; hoes &#128111; &#128175;&#128175;"&#58399;&#58399;&#58399;&#58399;',
#  '"@whooligan__: can\'t stand a "I don\'t know what I want" ass nigga &#128564;" bitch*',
#  '"@wiganzlad: "@MarkyCrumb: "@gmail_shorts: I\'m on my way http://t.co/MqcZuXlbtT" love a #chav"hot" sexy scally fucker.',
#  '"@witmyRUDEass: These newly gay bitches don\'t kno how shit works"',
#  '"@witmyRUDEass: When a bitch don\'t want a real job they just become strippers lol" lol.',
#  '"@wodaeeex3: Awww Meat Meat In His Feelins"i ainn n my feelings bitch',
#  '"@wodaeeex3: I Want Snake Bites , MY Industrial Piercin &amp; A Tattoo"Dem hoe accessories dea &#128064;&#128064;&#128056;&#9749;',
#  '"@worldtraveIs: Baby albino &#128034; http://t.co/2tYTQJ3fec" @Meeeesh1395',
#  '"@worldwarzee_: these hoes ain\'t loyal."',
#  '"@xoxoclauudia: YASSSSSS, ORDERED CHINESE &#128079;" bitch you just ate tacos you fat fuck',
#  '"@z0mbiedance: I made that bitch lunch.',
#  '@elizabethbatman" Bitches love lunch.',
#  '"A NO BRAINER"\nBut as soon as this bitch gets rich in political power, her views will change!',
#  'POLITICAL WHORES!',
#  'http://t.co/ekEPSjWcyU&#8221;',
#  '"A pussy a day keeps the devil away" -@DoperThanYola',
#  '"Ain\'t that about a bitch"... What does that mean?',
#  '"All these bitches want a baby, I don\'t want no children."',
#  '"And bitch you must be lost" &#128514;&#128514;',
#  '"Baby I like being on your left side" no bitch you can\'t be there Cuz the street on that side and Twitter said I ain\'t real if you do',
#  '"Bae" sounds like such a ghetto word.',
#  'Use something else',
#  '"Batter the wee cunt Jewis" y cos he fucked my ex?',
#  "Emma isnt battering the girls I've nailed?Ive moved on,stop being a pussy n do it urself.",
#  '"Bleed out hoe!!!"',
#  '-Alexa',
#  '"Boolin\' in the bando wit a few bitches"',
#  '"Brownies for my brownie" I love this movie.',
#  '&#128517;',
#  '"But I need a bad bitch that\'s hotter than me" might be the realist shit PartyNextDoor ever said.',
#  "That's how I be feelin everyday",
#  '"By the way we do punch bitches."',
#  '"Caesar is home" RT @Naewoodster: &#8220;@MjaySkillz: https://t.co/mw5KAojKXB"theres so much this bitch looks like.',
#  'Lets start with ape shit&#8221;&#128557;&#128557;"',
#  '"Chinese Maverick: We were communicating Comrade , u know giving the imperialist Yanks the Birdie" https://t.co/38GZ1jerPS',
#  '"Dad say hi to my snapchat" \nDad "&#9996;&#65039;&#9996;&#65039; duces bitch" &#128514;&#128514;&#128553;&#128553;',
#  '"Do you believe these hoes are not in fact loyal?"',
#  '"I disagree with that, I do believe they are in fact the loyalest bunch,these hoes"',
#  '"Don\'t know no ugly bitches!',
#  'Don\'t know no broke niggas!"',
#  '--@Kevin_Gates',
#  '"Don\'t make me make you fall in live with a nigga like meee..." The birds 1&amp;2 are my favorite songs by Weeknd',
#  '"Don\'t worry about the nigga you see, worry about the nigga you DON\'T see... Dat\'s da nigga fuckin yo bitch."',
#  '"Don\'t you ever give my pussy away.',
#  'You keep it tight, alright?"',
#  '"Dropped a stack cause bitch I\'m ON".',
#  '-@1PoloBoy \nSong called "Dope".',
#  'Download the mixtape here: http://t.co/LaCZ1e6TG7',
#  '"Dumb bitches do dumb things"',
#  '"Eat the pussy like a real nigga hungry"',
#  '"Eff it.',
#  'Let\'s go after the cripple."',
#  'http://t.co/kSaMx1JPfV',
#  '"Everything look better with a bitch next to it"',
#  '"Facto @ShaunaSayomi: Who cares if you a hoe when your ass looks like this?',
#  'http://t.co/CJdT987aqf"',
#  '"For every bad bitch there is a nigga tired of fucking her"',
#  '"Foreign chick, no lie.. Man that bitch Beautiful"',
#  '"Fresh nigga so you kno I need a clean bitch... Who kno I\'m working cuz I wanna see my team rich."',
#  'http://t.co/Cgx3HNAK9A',
#  '"Fuck 5/0 I make my own rules.',
#  'Suck my dragon balls bitch call me goku"',
#  '"Generate ASCII boxes with NodeJS" all I see is the ability to bring flappy-bird in node via ASCII tubes and bird ^_^ http://t.co/lRJWDFhv7T',
#  '"Get me that shit bitch you is fine bear"',
#  '"Get your ass back to Detroit ya fuckin\' wigger!"',
#  '"Girls that I dated, its okay I ain\'t mad yo, unless you stabbed me in the heart, no love hoe"',
#  '"HOW DO YOU KNOW MY TWITTER PASSWORD" bitch please',
#  '"Have you seen my shows?',
#  'Have you seen my hoes?',
#  'If I wasn\'t hot would they be so thick?"',
#  '"He a bitch for hitting that hoe" &#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;',
#  '"He married to a white woman... lucky sum-bitch" - Uncle Ruckus',
#  '"He wanna be my nigga, but I\'m just trinna be his savings account &#128553;" &#128514;&#128557;&#128514;&#128557; omg imma funny ass bitch man, but that\'s Real Shit &#128175;',
#  '"Her great grandmas a hoe,her grandmas a hoe,her moms and a hoe, and she\'s a hoe!',
#  'It\'s a long line of hoes!"',
#  '-Grandpa Carl everyone',
#  '"Hey go look at that video of the man that found the kidnapped girls in Ohio........what a nigger" - #shitmybosssays',
#  '"Hey pussy you still there?"',
#  '"How about we draft all those gung-ho folks and send them to Afghanistan or other war zones so they can show their... http://t.co/sR1zceHx',
#  '"How hotter than is it?"',
#  '"A bitch."',
#  '"How u talking to hoes bout bro n em.. Why you talking to hoes bout bro n em"',
#  '"How you doing, crazy bitch?"',
#  'is hilarious!',
#  '"I KNOW my shoes dirty as fuck, whatever, bitch.',
#  'You don\'t have to call!"',
#  'Like, negro... one of the first things they LOOK at is shoes, dog',
#  '"I am a thrill billy..with a hillbilly heart."',
#  '-@billyraycyrus.',
#  'HAHAHAHAHA Jesus Murphy!',
#  '"I call him my bitch" @MaKennaM_',
#  '"I can\'t handle no liquor...',
#  'But these bitches can\'t handle meeedd" - Chief Sosa',
#  '"I don\'t chase after dudes...',
#  'I chase after bitches."',
#  '- Edgar Bautista',
#  '"I don\'t love these hoes, baby It\'s me and you forever"',
#  '"I dont even need a picture of tamar, that bitch is beat in every picture"&#128514;&#128557;&#128514;&#128514;&#128514;',
#  '"I dont have hoes" &#128564;',
#  '"I found a new way to chug you have to open your mouth alot" #shitallysays',
# ...
#  '"I would rather you call me bitch than sir" -my manager',
#  '"I\'ll beat on that pussy so hard"',
#  '"I\'ll slit your throat-neck" http://t.co/ChFFSDeDdd',
#  '"I\'m a funky ass honkey."',
#  '- @jtimberlake \'s shout out to @macklemore tonight before "Cabaret" &#128514; #JT2020Tour',
#  '"I\'m comparing KFC to the pussy" @MaxOn_MaxOff5',
#  '"I\'m downloading you a new personality and ordering you a new face!',
#  'You bitch..',
#  'I love you.. Goddamn it!"',
#  '-Axl Rose yelling at his sex robot',
#  '"I\'m feelin like Malcolm in the middle, these bitches surround me they can\'t miss em"',
#  '"I\'m gonna piss on your dimple @SoNi99a_: Stop wasting prayers on trash teams lol"',
#  '"I\'m probably your main bitch chocolate dipped cinnamon apple"',
#  '"I\'m sick of his shit man @JonnieSantana: Sit his bitch ass, I\'m fed up bro RT "@80sbaby4life: Geno threw yet another pick smh""',
#  '"I\'m sorry I fucked yo bitch...',
#  'But she really dig a nigga" @KingL',
#  '"IBS" irritable bitch syndrome.',
#  '"If you love her then hide yo bitch so you\'ll keep shorty."',
#  '@wizkhalifa',
#  '"If you talk back to me you ain\'t getting no pussy."',
#  'Me: http://t.co/vgnwcFgvSJ',
#  '"If you\'re a bad bitch put your hands up high" \nEvery girl in the room starts waving there hands around.',
#  '"Imma tie that bitch up in the basement and donkey-fuck her ass for two weeks straight" hahahahahahahahaha #50centmovie #beforeiselfdestruct',
#  '"In My Mind"\nGotta be the dumb hoe anthem...',
#  '"Is that an albino Mexican?"',
#  '"No dad, he\'s Asian."',
#  '"It takes a true directioner to accept Larry" You know what bitch its fans like you that make the boys cry.',
#  '#ThankYouPaulForConfirmingLarry',
#  '"It\'s allegations, were u in the bedroom?',
#  'Did u see it?"',
#  'Words of a naive &amp; blind bitch.',
#  'We know ur husband cheated on u. Ramona is dumb!!',
#  '!',
#  '"It\'s never too late to tag a bitch.',
#  '"- @CyFyre',
#  '"It\'s the dykes" -hunter dyke with a dyke http://t.co/LGtw3AWMeh',
#  '"Julia Roberts, you\'re a ho" @LaurenGardner8 #NottingHill',
#  '"Just follow the yellow brick twitter."',
#  '"LMFAOOOOOOOOOOOOOOOOOO @bb_brooks: If your pussy is good but my mama don&#8217;t like you?',
#  'Guess who gotta go&#8230;&#8230;&#8230;..my mama."',
#  '"LOL, cripple!"',
#  '- Wendy Davis.',
#  'RT @MailOnline: Scientists create remote-controlled chick to study shy penguins http://t.co/mT3B09Slod',
#  '"Let\'s do nips ahoy and spank me maybe"',
#  '"Let\'s kill cracker babies!".',
#  'WTF did I just hear????????',
#  'WOW.',
#  '"Like... correct me if I\'m wrong but...',
#  'Doesn\'t pimpin involve \'smackin bitches for money\'?"',
#  '"Lmao @BlackBeauty515: &#128514;&#128514; RT @80sbaby4life: Pound cake look like pussy &#128514; http://t.co/UFYwCC9xCI"',
#  '"Lmao @SWILLA_LO: The d.rose adidas are lighter than my phone .... Shit is retarded"',
#  '"Mam, Ren&#233;e doet in haar rol net of ze ongesteld is Wat is ongesteld?"',
#  'Van dat soort vragen waar je denkt: hoe leg ik die weer uit.',
#  '"Maybe she wants to be more than your friend or maybe she\'s a stupid bitch.',
#  'You never know until you make her cum."',
#  '&#128514;&#128514;&#128514;',
#  '"Mine plays DMX and kirk Franklin smh @_justcallmeBRIT: Well my neighbors are ghetto .',
#  'They get up at like 5am and beat their kids."',
#  '"My grandma used to call me a porch monkey all the time... Come to think of it she did refer to a broken bottle as a nigger knife" &#128563;',
#  '"My momma told me to tell you to mind yoooo damn motha fuckin business you 2+2 not knowin what it is bitch!!!!!!"',
#  '"My nips are freeeeezing...and that\'s not okay because they\'re slicing through my bra...."\n&#128514;',
#  '"My twitter was hacked" = I\'m too pussy to admit that I said it and now I want to act like I never said it.',
#  '"Nah girl I ain\'t gon be able to make it, it\'s been tight since Russ loss his job" you in the back like "damn bitch really"',
#  '"Nah its You @NoMeek_JustMilz: &#128514;&#128514;&#128514;&#128514; yo i thought some1 photoshopped my face on that faggot smmfh...i hate yall" http://t.co/5e2fkQ3Q2T',
#  '"New Flame" the song of the yr lol that bitch SUPER run like',
#  '"Niggas always yelling "Fuck bitches, Get money" meanwhile they\'re broke and still want the bitches&#8230;."',
#  '"Niggas be pressed for pussy, Eeeeeen nothin"',
#  '"No bitches " - nan',
#  '"No boats and hoes please thanks" - Mom',
#  '"OVO" &#8220;@Allthingsfresh3: &amp; kendrick lamar still trash&#8221;',
#  '"On top of that, she just a pregnant ass sorry hoe.',
#  'Aint never got no money.',
#  'Even her water broke."',
#  '- @TallTrappin88 #RIPTALLT',
#  '"Only a couple of Red Sox have gotten past first base."',
#  "I'm dying laughing.",
#  'Maybe the Yanks need to teach them some game.',
#  '"Our people".',
#  'Now is the time for the Aryan race 2 stand up and say "no more".',
#  'Before the mongerls turn the world into a ghetto slum.',
#  '1488',
#  '"Pistol whip my Dickau, shoot yo bitch club up."',
#  'Sometimes freestyles be freestyles.',
#  "And I'm okay with that.",
#  '"RT it for me.',
#  'Please and thanks @BmorePocahontas: Did a pierced pussy just come across my timeline &#128528;"',
#  '"Remy Machiavelli send shots to ya belly" &#128553; my bitch &#9994;',
#  '"Roberto you are one nasty hoe"',
#  '"SORRY JB FAN&#65292;REALLY JUSTIN COME BACK".',
#  'That is the top comment on a Justin Timberlake video with 10 million views.',
#  'Son of a fucking bitch!',
#  '"Searching" the incredible story of 1 white man\'s quest to find the ingredients necessary to make Caribbean Jerked Chicken in redneck land',
#  '"Selling my soul for material wishes: fast cars and bitches" #Tupac #smile #remix',
#  '"Shake that Bear ... aka two rednecks having sex on a dead bear"',
#  '"Shall I compare thee to a summer&#8217;s day?',
#  'No, a summer&#8217;s day is not a bitch."',
#  '"She gotta shape up her pussy lips tho @PostPrettyPussy: Whole wheat organic pussy http://t.co/kq0R0A7z2g"',
#  '"She said wigga man you rich...take the du-rag off" http://t.co/jb7J3zSbam',
#  '"She was a bitch anyway"',
#  '"She\'s from Florida so you\'ve got to do the sniff test in those swamp pussies" &#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128553;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;',
#  '"Slow the fuck down, bitch, I know where you live!"',
#  'Classy young lady.',
#  '"So he\'s a good football player...but he still acts like a nig"',
#  '"Stop being a pussy, son, and shove that needle into your own heart!"',
#  '#afterearth',
#  '"Stop looking us and go eat some pussy, you yuppie fucks."',
#  '"Takin it straight to dirt, why finger the pussy when I know I can put my dick in it?"',
#  '@xErnee18',
#  '"That ain\'t bro moves, that\'s hoe moves"',
#  '"That girl is plain looking borderline ugly &amp; chunky".',
#  "Hey at least she's got a nice smile &amp; a great personality.",
#  '"The devil grows inside the hearts of the selfish and wicked\nWhite, brown, yellow and black color is not restricted"',
#  '"The water isn\'t yellow, I\'m a healthy student"',
#  '"These hoes ain\'t loyal"',
#  '"These hoes keep callin but I ain\'t pickin up"&#127926;&#127926;',
#  '"These sour apple bitter bitches, I\'m not fuckin wit em"',
#  '"They Faggots @JonnieSantana: Orioles petty as fuck...got swept up outta this bitch"',
#  '"They have some ghetto ass bands" * gets snuck* &#128514;&#128514;&#128514;&#128514;',
#  '"They have to.',
#  'That division is trash @NoMeek_JustMilz: Saints gon win the NFC South...watch"',
#  '"This is for all the fans that waited, the bitch niggas that hated / Old hoes we dated, look mama, we&#8230; http://t.co/sNRY6A7VYB',
#  '"This is for my ghetto motherfuckers" -Missy Elliott',
#  '"This recipe calls for a leftover brownie.',
#  'What the hell is a LEFTOVER brownie?',
#  "That's just a brownie you haven't eaten yet.",
#  '"-@EricaNadine26',
#  '"Those ratchet broads don\'t represent me but YOUR white ass can\'t talk trash about them \'cause you on racist shit" Black',
#  '"Trust noneeee, bitch I don\'t "',
#  '"Twitter is twitter" bitch twitter is life',
#  '"Two roads diverged in a yellow wood, and I chose the one to J&#246;tunheimr"\n- Robert Frost Giant',
#  '"U got my 200K bitch nigga"--Al Haymon to Antonio Tarver',
#  '"Uh-uh, what do we have?',
#  'Your empty heart, my empty bottle, a yellow cab.. That you would like to catch cuz yo latest ex made u mad..',
#  '"Used to have a girlfriend, now all I got is hoes..',
#  'I was lookin for a good girl, but she was fuckin on the low."',
#  '"Virgin pussy " () " , regular pussy " ( ) " , Oomf pussy (_________________________)',
#  '"WHAAAAAAT!',
#  'LMAOOO!!!',
#  '@Cromotoasted: @creepgoddess that\'s why I luv u fat bitches cuz y\'all got some big ole titties and phat booties"',
#  '"Walked in that bitch like, NIGGA WE MADE IT!"',
#  '"We hate niggers, we hate faggots and we hate spics"-kkk rally',
#  '"We\'re out here, and we\'re queer!"',
#  '" 2, 4, 6, hut!',
#  'We like it in our butt!"',
#  '"Well bitch, biology said..." &#128514;&#128514;&#128514;',
#  '"What I do?',
#  '@betysweetcocker: Gotta report you as spam RT @80sbaby4life: Ladies RT if your head game better than your pussy"',
#  '"When im done with a hoe i pass her to the squad" G!!!!!!!!!!!!!!!!!!!!!!!',
#  '!',
#  '"Who the fuck you callin jiggaboo, nigga?!"',
#  '"Why people think gay marriage is okay is beyond me.',
#  "Sorry I don't want my future son seeing 2 fags walking down the street holding hands an",
#  '"Why u being such a little bitch chris you ain\'t six bitch" - Allisons Mom',
#  '"Why would I want to play with some pussy?"',
#  '- @jimmyfallon *DEAD* #SNL',
#  '"Why would you wanna be the Green Ranger?',
#  'He\'s evil!"',
#  'Duh bitch',
#  '"Why would you want pussy on your side burns?..',
#  'Thats a good question" @_hy0ung hahahahaha &#128514;',
#  '"Will shank a bitch for ceviche"',
#  '"Work" - @tydollasign Gets me through those rough days hahaha #hoes',
#  '"Wow you are a bitch" \n Yes that\'s already been established, anything else you have to say?',
#  '"Y\'all forget he has his brand new baby girl at home" bitch the cookies are burning',
#  '"YAH" has said in his word that the Mtzra\'ym(egyptians) are his people and Ysrah\'al is his inheritance and the Kushite(ethiopians).....',
#  '"Yaoooooooo @yea_im_JAMAICAN: Mawnin yardies!',
#  '&#128154;&#128155;&#128536;"',
#  '"Yo bitch on the horn.',
#  'Tryna shoot a porn."',
#  "- @KingL That's T shirt worthy Tony",
#  '"Yo can I sublet your pussy" #ShitFahdSays',
#  '"Yo feet smell like my puss" &#128514;&#128557; Whut ?',
#  '"Like flowers bitch" &#128514;&#128557;&#9995;&#128553; omg',
#  '"Yo mama, bitch."',
#  'RT @TheAceTJShow: What was the ONE sentence that ended your relationship?',
#  '"You ain\'t gunna do shit spear chucker"',
#  '"You ain\'t my bitch" is my favorite response to long texts',
#  '"You and yo boys some pussy cats."',
#  '"You are a cunt"',
#  '"You can pull more pussy with a dodge and collect them panties alright."',
#  '-stormy and jake &#128514;&#128514;&#128514;',
#  '"You can take someone out of the ghetto, but you can\'t take the ghetto out of them."',
#  '"You don\'t like us colored folks, what the he\'ll you\'re not colored you white fucks" &#128514;&#128514;&#128514;&#128514;',
#  '"You got hella hoes" http://t.co/ZN1A0gsTpc',
#  '"You hit no lights, no line for toco bell at 2 in he morning, and Diana\'s back in her house.',
#  'It\'s a miracle" - Charlie @dianaaaxo',
#  '"You look cute today :)"..',
#  '"Really?!"',
#  'Helll no, swerve hoe!',
#  '"You look like little birds help you get dressed in the morning"',
#  '"You ol trout mouth ass bitch" \nDEEEEAAAADD',
#  '"You talk like a fag and your shit\'s retarded.',
#  'But that\'s cool scro, lot\'s of tards out there living total kick-ass lives!"',
#  '"You took our land so you could make each other retarded in DIAPERS?',
#  'Sure....use our image....cool...." #redskins #NFL #concussion #jokes',
#  '"You\'re a garden rose, and that bitch is a weed."',
#  '"You\'re fucked up" \nNo shit you dumb ass cunt now go post pictures if your flat ass titties on ig slut',
#  '"Your a queer".',
#  '&#128530;&#128530;&#128530;&#128530;',
#  '"Your homeboy looking bad and you giving cash to them hoes"',
#  '"Your teeth are like the stars."',
#  '"Aww thanks!"',
#  '"Yeah... yellow and far away from each other."',
#  '"Yup.',
#  'Fuck em @Aloha_Hoesss: Playing like trash RT @80sbaby4life Clippers don\'t wanna play lol"',
#  '"ain\'t it time for you hoes to get out of here" LOL this is what Ariana\'s mom says to us',
#  '"are we bitches?"',
#  '- @chellyhernandez',
#  '"ayo i even kill handicapped and crippled bitches/look at my scalp real close and you\'ll see triple sixes"',
#  '"bitch freak my shit"',
#  '"bitch my vagina is a little more resilient than that" -@rosestokoe',
#  '"but I love him" nah bitch that ain\'t love.',
#  '"but pussy is the root of all drama an attribute put up in they head by they mama."',
#  '"call me Keyshawn Johnson cause im catchin erry hoe"',
#  '"captain save a hoe" is the most annoying phrase',
#  '"day of judgement everybody gonna be looking at the big jumbotron watching me fuck this majjinn buu bitch"',
#  '"don\'t let your side bitch settle in, I might have to headbutt you Evelyn"',
#  '"dont show me no bitch unless she look like Dolly Parton!!!"',
#  '"fuck you you pussy ass hater go suck a dick and die quick" - Someone, to me, in Youtube comments.',
#  "I think we'd be good friends.",
#  '"hick and raver is a venn diagram that has a very large intersection"',
#  '"hoes suck my dick cus i look like john stockton hit em wit the choppa, luke i am your fatherrr" - @LILBTHEBASEDGOD',
#  '"if i wasnt in a work place id deck you" aye fucking right, I\'d give you a tyson 4 combo nd end you with an uppercut.',
#  'Shut the fuck up bitch',
#  '"if she can suck your dick with a dip in, she\'s not only a keeper but a true redneck woman."',
#  "- Kim's Dad.",
#  '"im gonna rip that bitch apart"\n"rip what apart"\n"lol"',
#  '"its britney bitch" - the bible (leviticus 7:58) http://t.co/ZoAkn1ZlHm',
#  '"niggas bitches bitch ass niggas dike ass hoes black ass and bright ass hoes fag tags and scally wags"',
#  '"no pussy, or not tryna go to the studio, don\'t CALL my mufuckin crib like that, god.',
#  'Yo.',
#  'Word up god I will BUSS YO SHIT, god, word up"',
#  '"oh ya these hoes think they cute in skin tight cat suits assuming that they bodies to boomin to dispute"',
#  '"omg this bitch is fucking stupid I swear blah blah blah" *a week later* omg ilysm bae ur my best friend I swear',
#  '"on my way to fuck your bitch in the name of The Lord" - Mr. Race',
#  '"poor whitey" http://t.co/3UkKeyznz8',
#  '"riding with my bros still don\'t trust these hoes"',
#  '"this weekends going to be fabulous" naa man, you\'re seeing nae cunt.',
#  "If you do they'll be koed in 2 seconds flat.",
#  'Hate u.',
#  '#fuckgm',
#  '"whatever you are, be a good one."',
#  '-Abraham Lincoln, this quote is not for yall hoes!',
#  '"when guys say "Latinas &gt;" they mean the Kim Kardashian looking girls not you bitches that shaped like a mini fridge &amp; smell like tortillas"',
#  '"when rappers say twat it makes me feel weird" &#128514;&#128514;&#128514;&#128557;',
#  '"you better pipe your pussy down over there"- @EsEx_Ruskii&#160;lmao wth does that even mean?',
#  '"you fucking pussy you couldn\'t even beat your dick."',
#  '- Angry Youtube Comment',
#  '"you\'re being a cunt right now" -@RQ978',
#  '# That son of a bitch moment when it rains and you forget your car windows are down',
#  "#10ThingsThatGetsOnMyNerves Needy hoes, ratchet Hoes, sideline hoes, Beggin' hoes, dumb hoes, looking for love on Facebook hoes..",
#  '#11 get to hit any bitch on campus he wants to',
#  '#1personidbitchslap @Khamruz.',
#  'Fa blowin my tl.',
#  'Up like a bitches spare tire leavin dairy queen',
#  '#2013Faves RT &#8220;@grahamorama: #Snoop and #Justin are having so much fun at this Charlie Wilson tribute #BETAwards https://t.co/C6NHwUBlXN&#8221;',
#  '#2013TaughtMe how pussy feels &#128514;&#128076;',
#  '#5WordsAfterSex is that all pussy bitch?',
#  "#AZmonsoon lot of rain, too bad it wasn't enough to wash away the teabagger racist white trash in the state.",
#  '#Tcot #teaparty #azflooding',
#  ...]

# %% [markdown]
# # stemming and stopwords

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stemmer = PorterStemmer()

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    stemmed_words = []
    for word in words:
        if word not in set(stopwords.words("english")):
            stemmed_words.append(stemmer.stem(word))
        sentences[i] = " ".join(stemmed_words)
        
sentences
# Out:
# ['! ! !',
#  "rt @ mayasolov : aswomann'tcomplaincleanh .",
#  '& amp ; manalwaytaketrash ...',
#  '! ! ! ! !',
#  'rt @ mleew17 : boydatcold ... tygadwnbadcuffindathoe1stplac !',
#  '!',
#  '! ! ! ! ! ! !',
#  'rt @ urkindofbranddawg ! ! ! !',
#  'rt @ 80sbaby4lif : youeverfuckbitchstartcri ?',
#  'youconfusshit',
#  '! ! ! ! ! ! ! ! !',
#  'rt @ c_g_anderson : @ viva_baslookliketranni',
#  '! ! ! ! ! ! ! ! ! ! ! ! !',
#  'rt @ shenikarobert : theshithearmighttruemightfakerbitchtoldya & # 57361 ;',
#  '! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !',
#  '`` @ t_madison_x : theshitblow .. claimfaithsomebodistillfuckho !',
#  "& # 128514 ; & # 128514 ; & # 128514 ; ''",
#  '! ! ! ! ! !',
#  '`` @ __brighterday : isithateanothbitch ..',
#  "igotmuchshitgo ! ''",
#  '! ! !',
#  "! & # 8220 ; @ selfiequeenbri : causi'mtirebigbitchcomeusskinnigirl !",
#  '! & # 8221 ;',
#  '`` & amp ; mightgetyabitchback & amp ; ``',
#  "`` @ rhythmixx_ : hobbiinclud : fightmariam '' bitch",
#  '`` keekbitchcurveveryon `` loliwalkconverslik .',
#  'smh',
#  '`` murdagangbitchgangland ``',
#  '`` sohoesmokelos ? ``',
#  'yea ... goig',
#  '`` badbitchthinglik ``',
#  '`` bitchget ``',
#  '`` bitchniggamiss ``',
#  '`` bitchplzwhatev ``',
#  '`` bitchlov ``',
#  '`` bitchgetcuteverydayb ``',
#  '`` blackbottl & amp ; badbitch ``',
#  '`` brokebitchcanttellnoth ``',
#  '`` cancelbitchlikenino ``',
#  '`` cantseehoewontchang ``',
#  '`` fuckbitchdontevensuckdick `` & # 128514 ; & # 128514 ; & # 128514 ; kermitvideoboutfuckig',
#  '`` gotyabitchtiptoehardwoodfloor `` & # 128514 ; http : //t.co/cou2wq5l4q',
#  '`` pussiliplikeheavendoor `` & # 128524 ;',
#  '`` hoehit ``',
#  '`` metpussioceandr .',
#  'gavepussipil `` & # 128524 ;',
#  '`` needtrippibitchfuckhennessi ``',
#  '`` spendmoneywantbitchbusi ``',
#  '`` txtoldbitchnewbitchpussiwett ``',
#  "`` 'dsayimbackoldoldbitchwouldgetexcit `` & # 128524 ;",
#  '`` aintboutmurdergamepussiniggashut ``',
#  "`` 'retoeain'tdonepussistink ``",
#  '`` imdonebitterbitchwrap .',
#  'angribirdthereapp ``',
#  '`` yabitch ``',
#  '`` aintnothcutbitch ``',
#  '`` jumeetsonyamaneassbitch `` # shot',
#  '`` lamecrihoethattearclown ``',
#  '`` likesnoopsaid94dontloveho ``',
#  '`` mommasaidpussicatinsiddogh ``',
#  '`` hatehoefavorit `` # 2mw # sevenon # http : //t.co/bmdsvmc3rc',
#  '`` nicegirlbad , makegetnaughti .',
#  'badyelloho , realnicebodi .',
#  "downsouthchick , likeemrealthick '' http : //t.co/bzrdl3kf7u",
#  '`` pimppimpho `` futurvo',
#  '`` postpicturpussiget200lik ``',
#  '`` pussipowerdrug `` & # 128517 ; # happyhumpdayhttp : //t.co/r8jsymib5b',
#  '`` quickpiecpussicalldr ``',
#  '`` runroundlikebrandnewpussithatboutgetfuck ``',
#  "`` bitchevenworst'llsendguy ``",
#  '`` hoelikeniggaspendmoneytalkbout ``',
#  '`` donttrustniggabitch ``',
#  '`` yallniggabcufhoecausyallaintneverbitch ``',
#  "`` dodgbullet `` & # 128517 ; & # 8220 ; @ darealkha : `` alldabitchicutpregnantbound .... thankgod & # 128591 ; '' & # 8221 ;",
#  '`` youngpillchamberlainbitchlovemus ``',
#  "`` & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; @ vandalsavage_ : teannatrumpprobablcleanertwitterho ......... ''",
#  "`` & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; @ dahomiefuzz : gayniggacouldn'twaitactlikebitchtonight ''",
#  "`` & # 128514 ; & # 128514 ; & # 128514 ; @ the_paradox : andimastealcatnreplacpitbul & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; rt @ 80sbaby4lif : @ the_paradoxhebitch ''",
#  "`` & amp ; 'sgonealwayho ''",
#  "`` ... sonbitchtooktictac . ''",
#  'ilikemovi .',
#  "`` .. alliwannagetmoneyfuckmodelbitch ! ''",
#  '-russelsimmon',
#  "`` @ 2015seniorprob : iprobabl & # 8217 ; mindschoolmuch & # 8217 ; dealbitchassteach '' .",
#  'retweet',
#  "`` @ a7xdemeri : i'mfuckfagsaid ''",
#  '`` @ arizzleindacut : femalthinkdatepussicut ?',
#  "http : //t.co/vxbjg26gsz '' stuffmakepussi ?",
#  "`` @ addicted2guy : -simplyaddictedtoguyhttp : //t.co/1jl4hi8zmf '' woofwoofhotscallilad",
#  "`` @ adorebellaaa : haveyaeveraskbitchbitch-kanyvo '' ye",
#  '`` @ adorezoey : howugonebringursidebitchgameyouknowyagffriend ? !',
#  "& # 128553 ; & # 128553 ; & # 128553 ; & # 128553 ; ''iswear ! ! ! !",
#  '!',
#  "`` @ allaboutmanfeet : http : //t.co/3gzupfumev '' woofwoofhotsol",
#  "`` @ allyhaaaaa : lemmieatoreo & amp ; dish . ''",
#  'oneoreo ?',
#  'lol',
#  "`` @ almightywayne__ : @ jetsandaswish @ gook____bitchfuckuhttp : //t.co/pxmga68nc1 '' mayb'llgetbett .",
#  'justhttp : //t.co/tprevwfq0',
#  "`` @ almightywayne__ : fuckredmalonmanbitchassniggah '' couldpleasusecompletsentenc ?",
#  '`` @ arizonasfinest6 : whieggplantemojido ?',
#  '`` saylooklikescreamlmao',
#  "`` @ autoworid : hennesseyvenomgt & # 128584 ; http : //t.co/i8egmnkaj9 '' 'sonesexibitch",
#  "`` @ bossbytchh : himsehpussiwettershowercurtain .... # ahmesehwet '' & lt ; lmao !",
#  '!',
#  "`` @ bro_hen314 : # eaglesneveri # eaglneedseepicipostbitchsaidracistshit ''",
#  "`` @ bvsedchink : yofuckskateboard , y'allwoodpushfaggotman , balllifehttp : //t.co/vbczp6hmt7 '' @ amjemiebenn",
#  "`` @ babyanimalp : babimonkeybathtimhttp : //t.co/7kpwadlf0r '' awwww !",
#  'thisooooador !',
#  "`` @ baylaagottabodi : & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; iain'tshit . ''",
#  'damnskippilol',
#  "`` @ beeasyjrizzi : ueverkillantsidewalkthinkdamnniggawaygetpussi '' nobsmustb & gt ; 30 % chanc",
#  "`` @ beenbasedb : @ _kudabrazyyhttp : //t.co/luubgl9y5u '' 0ring0mvp0bitchlol",
#  "`` @ beenflynsolo : ppltalkbadghetto/hood ... kidgrow , niggafunnnnnnn ! ''",
#  "`` @ bestproadv : thefacttattoo ... tattoohttp : //t.co/zwnbhpdz8 '' 'spussitattoonippl",
#  "`` @ bill215_ : & # 128175 ; & # 128175 ; & # 128175 ; rt @ nel_aydenbitchwantactlikeniggabad & # 128553 ; & # 128553 ; & # 128553 ; shitaintcuteee '' niggaactlikebitch ..",
#  '`` @ bitchjones92 : getworshipbitch !',
#  "http : //t.co/r37cejcj '' woofwoof",
#  '`` @ blackchiquitita : wow .',
#  "rt @ thatmanpalmi'mlost .",
#  'arebuttcheekpierc ?',
#  "http : //t.co/yn6guyouq6 '' yeah'sho",
#  "`` @ blacknerdjad : ok , si . ''",
#  "she'dratherbrokebitch ?",
#  "* shrug * 'lltellwork",
#  "`` @ blackman38tid : @ whalelookyh @ howdydowdy11qu '' gaywad",
#  "`` @ brokenpiecesmsc : @ itsnotadamfaggotreadtweetdatk '' n'tevenfunnilol",
#  "`` @ brosconfess : thibitchungrathttp : //t.co/06e77bgwbx '' fr ..... lulwhor",
#  "`` @ cashandboobi : ikidnapyobitch ''",
#  "`` @ cb_baby24 : @ white_thunduhalsarabsss '' hebeanersmhtellhemexican",
#  "`` @ ccobey : @ aydanmccoyhappibirthdaynig '' thankyo",
#  "`` @ chlldhoodruin : urteachertelluuhomeworkhttp : //t.co/rkk5vawij1 '' bitchneedgo ! !",
#  '!',
#  "`` @ caelang15 : `` @ 22edham : @ caelang15niggaeathoelol '' hellyealoljohnpaul '' niggasaidjohnpaul .. http : //t.co/osipbkpr9h",
#  "`` @ canifuckornah : whatwouldy'allliluglibaldheadbitchstopmakemake-up & amp ; weav ? ''",
#  "`` @ carelessone92 : leafbetterwindamngameigoriotshit # earlychristma '' betterstartlootnig",
#  "`` @ causewereguy : gobackschoolsuckdickhoeattend . ''",
#  "`` @ causewereguy : onwayfuckyobitchhttp : //t.co/j906t5ze2r '' 9yearold",
#  "`` @ celeynichol : @ white_thunduhcomeneverbringfood '' dontcarretard",
#  "`` @ chadmfverbeck : ifrichnown'tshowhellatinderhoeimfriendanymor '' chillibroughtlikelike8propl",
#  "`` @ chandlerparson : howboutcowboy ! ! ! ! ''",
#  'shutuppussi',
#  "`` @ clicquotsuav : lmaooooooooooonigga @ krillz_nuh_carhttp : //t.co/aanpsujmyi '' & lt ; bitchwantlikedepressshit .. foh",
#  "`` @ coley_c : @ lil_aeriigirlknowispitgshit & amp ; golbv '' bitchplz",
#  "`` @ coley_c : letmakecoupltweetcuzzopag , iwon'tgettwitterjail .",
#  "`` lmaobitchn'ttrick",
#  "`` @ comedypost : harlemshakeexcusgofullretard30second . ''",
#  "`` @ comedytruth : amenmiley & # 128591 ; http : //t.co/p2kb2tfyxr '' okay , n'tneedactlikehoebc 's `` emotdamag '' foh",
#  "`` @ corybandz : oneloyalfemalwayyyyybetterho , idc & # 128175 ; ''",
#  "`` @ crhedri : pussilickpussi .... meowmeow # stopwhitepeople2014 & # 128049 ; http : //t.co/keegdcjs5k & # 8221 ; ' '' ' '' '' & # 128533 ;",
#  '`` @ dbab_holloway : check12thman .',
#  "# cowboysn '' evenfaggotnyfanstand",
#  "`` @ dgotbrick : whathappenvixenentbitch '' gotranthrewsidelikefoothilbitch",
#  "`` @ daedavidavi : @ white_thunduhimbitchokaynudepat & # 128554 ; & # 128527 ; & # 128056 ; ''wow",
#  "`` @ devilgrimz : @ vigxrart'refuckgay , blacklistho '' hold # tehgodclananywayhttp : //t.co/xuccwoetmn",
#  "`` @ diamondloudkush : thefuckwrongbitch ? ''",
#  'nobodiknow',
#  "`` @ dietrich1892 : yallshut : p '' makebitch",
#  "`` @ dionairish : ihat `` i'mpregn '' typebitch . ''",
#  "`` @ doyou_q : gotbitchdmin'teverread'em '' top3",
#  '`` @ domworldpeac : basebalseasonwin .',
#  "# yank '' thilovestart",
#  "`` @ dommoneek : littlstupidbitchin'tfuckyoooooouuuu .. ''",
#  "`` @ dreadheadari : realliaskdeadassserioutho , couldsay `` bitchwheet '' lol",
#  "`` @ dunderbail : i'mearlibirdi'mnightowl , i'mwiseworm . ''",
#  "`` @ edgarpixar : overdosheavidrugn'tsoundbadtonight . ''",
#  'ipussishiteveriday .',
#  '`` @ el_grillo1 : pitbullphotographaslovefairitalecreaturhttp : //t.co/q0sm89oolh & # 8221 ; * * fairitalecreatur .',
#  "`` @ ferocious_ghost : @ 1stname_bravoaw . ''",
#  "... fag , n'ttweet `` aw '' lol",
#  '`` @ flokid88 : aslonglakertrash , icouldcareless .',
#  "and'sreal. `` .",
#  'cc : @ benbalhahaha',
#  "`` @ frosstyy_ : @ h0rheydin'tsayanyththo '' kissfaggot",
#  "`` @ funnypicsdepot : `` iplaysocc , cheatgirl , wearkhakicolourcargo '' haircuthttp : //t.co/zuai7qwbir '' & # 128514 ; yup",
#  "`` @ g27statu : icouldgofatassbitchlap ''",
#  '`` @ gedmel:17misscal ! ! ! !',
#  "& # 128544 ; & # 128545 ; ''dayop.obitchtwitterfinnascreamn # freemoneymel",
#  "`` @ gtm_al : yasidebitchgottaknow'sruleshit .. anybodiaskcousinjerseythinkinboutmov '' lmmfao & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` @ gagatom1 : & # 8220 ; @ malefoot:3|amolopiehttp : //t.co/4qe1hdkk8i & # 8221 ; ''fuckyeah",
#  "`` @ girlthatsvont : thesehoethinkmeatwon'tslapass & # 128564 ; & # 128075 ; ''ainnabruh",
#  "`` @ girlthatsvont : yallbitchwitedgtalk & # 128553 ; & # 128564 ; & # 9995 ; '' & # 128514 ; & # 128514 ; & # 128514 ;",
#  '`` @ girlthatsvont : yallstillgotricktreatyearnah ?',
#  '`` hellyeahimadasweettoothbanditstealbitchbagnshit',
#  "`` @ girllssu : iwannasexmomfuckrightpussiicam '' damngothacklikefuck",
#  '`` @ gizzy_jones94 : ifkissueyeopenwatchbitch !',
#  '`` lmfao',
#  "`` @ goofstroop : youwouldacouldashouldaassho & # 128563 ; & # 128586 ; ''",
#  "`` @ gotti_ltf : happibdaybitchassnigga @ jetsandaswish '' preciatbitchrol !",
#  "`` @ hbmostdop : @ 1jay @ pipinhousesendbitch ''",
#  "`` @ hbmostdop : uglibitchlikei'mwcwduhbitchain'tnobodiel & # 128514 ; & # 128514 ; ''",
#  "`` @ halotgmg : @ 1stname_bravoniggaknowhackisackho . ''",
#  '... nah , ithrowlookpasslmao',
#  "`` @ heartlessfuck : gladi'mgetouttaatlanta .",
#  "nothbunchnigga & amp ; outtajail & amp ; dumbbitchmadkidfuckinem . ''",
#  "`` @ hermosaalma : thin'tghetto ..... 'ssmarthttp : //t.co/mpazq3jswf '' i'midc",
#  "`` @ hiimjorib : iwouldwifehoecuzwouldn'tcarecheat . ''",
#  '... forcrelationshipfirstplac ?',
#  "`` @ hornyfact : besingln'texcusho . ''",
#  '@ theonemiss_luu',
#  "`` @ hoskinsty96 : whiteboypowerbitch '' blackpowerbitch",
#  "`` @ hudgens_11 : letgetdrunk , getblow , spitshitsparkblunt & amp ; fuckho ! ''",
#  'browhitedudechil .',
#  "`` @ iscoutgirl : @ verbally_abruptbitchu '' aroundworldback .",
#  '?',
#  "`` @ itsyahboiray : @ anelylovin'tgetdicksuckyopartibadbitchi'mfrgoneset & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; '' * @ anelylov *",
#  '`` @ itsyesi : # oomfsoooocut .',
#  "butprobablhoelot . ''",
#  '`` @ jayten9 : inevericartoonalway @ _nuffsaid15savehoelmao .',
#  "http : //t.co/9ukd8wtz6x '' lmaodamncaptainsaveaho",
#  "`` @ jreebo : whowantgetnosebadboi # scalli # chav # sockfetish # stinkhttp : //t.co/feqxgn0w6i '' hotsoxleg",
#  "`` @ jamesynba : iwishibitchlikebrotherkeezi & # 128530 ; ''ooooowibet",
#  "`` @ jasminepor : ifdresscathalloweenbas . ''",
#  '... pussi',
#  "`` @ jewelxo : canpornhubgetgamestreamfeaturdumbbitchgtfo '' @ pornhubgetkati & lt ; 3",
#  '`` @ joebudden : stopscarechokesexubitchassnigga .',
#  '& # 8217 ; like. `` .',
#  'sayguyhitwomenb .',
#  'foh',
#  "`` @ johnny55perez : @ white_thunduhhawelliguessimakehoeloyalbro '' theyllneverloyalhoenig",
#  "`` @ kazatta : @ 1takehovohman .. `` 5 , molli , hofuckyase ? ? ' '' '",
#  '# fix',
#  "`` @ kelsiebelsi : you'remanrefereverigirlbitch ''",
#  "`` @ keyshawnswag : lmfaocatstartbeatshit '' niggafinalgotpussi ? ! ?",
#  'mynigga ! !',
#  '!',
#  "`` @ keyshawnswag : peelpeelbringbackrewindbacki'mmoveshaqlin '' ooooowtfsaidtrash ! !",
#  '?',
#  "`` @ kingcuh : @ 16stanleyioioalurecordhovinesaipehahahaha '' lolanywaaaaaay ..... haha",
#  "`` @ kinghendo95 : @ vondreaamnaw'soldtap .",
#  'newcov .',
#  "upcommixtap # kingofthehil '' yeahi'mwaithoemayn !",
#  "`` @ kingteej_ : oldirtifootassbitch .. ''funni .",
#  "`` @ king_shawn_6 : @ white_thunduh'sigetyellowflagamaz & # 128079 ; & # 128524 ; ''hellyeahniggi",
#  "`` @ kissmysmil : don'tgottimebitchactiniffi . ''",
#  "`` @ knightfann # ucfpinkparticomestayalivknightn ! ! ! ! ''",
#  'thistillearlibirdspeci .',
#  '# comeatmeut',
#  "`` @ kyranadiya_ : thesehoeain'tloy ; ain'thttp : //t.co/h1ubsvbkgl '' smfh & amp ; wondernobodidecentw",
#  "`` @ lcistj : bruh , studkeepthinki'msofthel .",
#  'askyagirlmanitimescreambitch .',
#  'ohokay .',
#  "stfu . ''",
#  'byeho !',
#  "`` @ lodycash : dripussibitchalwayblamecondom & # 128514 ; '' & # 128079 ; & # 128514 ; & # 128079 ; & # 128514 ;",
#  '`` @ lunarap : shutyobitchass !',
#  "http : //t.co/iemn1u0gm5 '' & # 128557 ; & # 128514 ;",
#  "`` @ laflaregodjosh : guccimanejaildropmixtapeverimonthhoecan'teventextback ''",
#  "`` @ latrobemark : youlovehoemoneywatwrongnigga ''",
#  "`` @ lebronvuitton : aloyalbitchburbwithoutdaddiissulikefindholographmewtwo . ''",
#  '... soundlikelol',
#  "`` @ lilfridayho : easicum , easiho '' that'sfact !",
#  "`` @ lifeasbro : charlisheenrealhttp : //t.co/gggdk3kov7 '' majorfuckrespectcharlisheen .",
#  "`` @ lightskingawdd : wishiba & # 128533 ; ''yougothoetho",
#  "`` @ lil_mike_12 : fucktwerkbitchcook ? ''",
#  "`` @ linniekravitz : @ wesgodlaflarbitchwtf '' http : //t.co/dasmycxodb",
#  "`` @ lipe_the_great : & # 8220 ; @ h0rheyd : `` @ lipe_the_great : shutzo '' fightpussi & # 8221 ; zoe ?",
#  "i'mgood , man . ''",
#  "yougoodma'am .",
#  'movealong',
#  "`` @ lolaaisdop : lmaofucksnakebitch '' @ em",
#  "`` @ loveable_aizah : bigbootihoeeverywhersheesh & # 128525 ; ''damn & # 127807 ; & # 128064 ; & # 127807 ;",
#  "`` @ mlbnetwork : staytun @ mlbnetworkupdatreport @ yanke1b @ teixeiramark258-10week '' @ dliming35 # bum",
#  "`` @ m_rad : & # 8220 ; @ dezdlt : `` iplaysocc , cheatgirl , wearkhakicolourcargo '' haircuthttp : //t.co/tycihd6pkw & # 8221 ; yelmfao '' @ soccerboy_04",
#  "`` @ madflyentist : oregonchokeeveriyeargetfieldtrashassprogram '' rft",
#  "`` @ mannydiesel : defcowboylolrt @ artoffloyd : terrelowenbesteagl & amp ; cowboyev '' .. dudecrilikebitchtv , romo",
#  "`` @ markroundtreejr : lmfaooooihateblackpeoplhttp : //t.co/rnvd2nlcdr '' thi'sblackpeoplnigg",
#  "`` @ master11_ : @ 20tolife_ @ gabrielastarrhowcouldubitch '' potent",
#  "`` @ maxmayo77 : http : //t.co/3jk4kr44x3 '' pissladpast .",
#  'iwouldlickdirtisoleslept .',
#  "`` @ maxmayo77 : http : //t.co/prrskknqrv '' lovefratboyw/softlongsol",
#  "`` @ maxmayo77 : http : //t.co/xpsc3makgj '' sexiladhotsolearch .",
#  "`` @ megamindnick : @ white_thunduhnahfamigottacheatho '' dependfemalfeel",
#  "`` @ mesha_noja : @ _vontethekidd & # 128079 ; & # 128079 ; & # 128079 ; & # 128079 ; & # 128588 ; ''igothicklol",
#  "`` @ migsmichelen : thinewtwitterconfusshit . ''",
#  'gobacksouthamericabitch',
#  '`` @ miikito_x3 : totomeanassvagina ?',
#  '`` ithinkpussicaustotosantilikenastipussi',
#  '`` @ mikelahenri : actualchoosuglibitch ?',
#  "& # 58381 ; ''herassmustfat !",
#  "`` @ mileycyru : bitchcouldn'tkillvibeyatri .",
#  "& # 127752 ; & # 127752 ; & # 127752 ; ''dilovemiley : *",
#  "`` @ montrell_ : i'mtirebitchsayilookmean .. & # 128530 ; ''niggabigaf , weartightshirt , grimeverybodi .",
#  "`` @ motherjon:10birdgrandkidmayneverse , thankclimatchanghttp : //t.co/xqmxhkaswthttp : //t.co/rbitegrnhm '' # climat",
#  "`` @ mvckfadden : `` staybeautibitch '' ''",
#  '`` @ nickiminaj : # wutkindarpurpl .',
#  "ceeele '' mangurljuplayin `` stupidho `` track .",
#  'butstillshitsumgurl',
#  "`` @ nastycopp : moneygettallerbitchgetblurri ''",
#  "`` @ newsomejad : iain'tneverseenbitchobsessnigga & # 128514 ; '' i'mobsessmin & # 128529 ;",
#  '`` @ nicholas_ted33 : kobestaytalktrash .',
#  "butlet'sforgethttp : //t.co/vh4tnekvtp '' @ j_austin12imeanton .",
#  'smh .',
#  "`` @ nochillpaz : `` atleasti'mnigg '' http : //t.co/rgja7cfoit '' lmfao",
#  "`` @ no_fakingg : peoplalwayaski'mmix . ''",
#  'shebadasianbitchlol',
#  "`` @ notoriousbm95 : @ _whiteponyjr_arizasnakecoward '' leastn'tcrippllikeheroroachlmaoo",
#  "`` @ osay_it_aint_so : & # 8220 ; @ ignorealllaw : fosterhomeimaginaritrash & # 8221 ; whoachil '' showeverythtf",
#  "`` @ officialreplay : ilowkeytir . ''",
#  '... tire , quietgosleepho !',
#  '`` @ prayingforhead : & # 8220 ; @ macklemro : stopbringweirdniggerment !',
#  "@ prayingforhead & # 8221 ; http : //t.co/cussdjesrk ''",
#  "`` @ prettyboss_brat : wen'tloveho & # 128080 ; & # 128581 ; ''",
#  "`` @ patrickquelo : ifyogirlcanthomeboyolweakbitchassnigga ! ''",
#  "`` @ patsfanjoe32 : @ d_palomino52ithinkworstadvicigav `` n'tpussispe '' lol ''",
#  '`` @ poemsporn : quottweetfavoritanim .',
#  '`` pussi',
#  "`` @ poetic_success : ihatestrippertel 're `` dancer '' .",
#  "hoe , balletdancern'tpoppussibeethoven .",
#  "youstripp ! ''",
#  '`` @ poffalici : andrewbri : poffdoublvision2beerpoff : ...',
#  "doublpussi & # 128526 ; ''smh",
#  "`` @ poobie_ : whenbitchtwerkcomput .... : `` inya & # 128089 ; , yadamn & # 128089 ; & # 8252 ; & # 65039 ; ' '' '",
#  '`` @ prodsjewel_ : & # 8220 ; @ sreadthepeac : & # 8220 ; @ yungmindless : @ peacepunkprincprinc , thiart .',
#  'http : //t.co/ephrwxmbhr & # 8221 ; noboditakinbitch !',
#  '`` @ quan1t0:61 % welfare/governaidclaimwhitepeopl .',
#  "soy'allblackslandertrash . ''",
#  "`` @ quan1t0 : thesebitchn'tcareplayrol . ''",
#  "`` @ queen_kaaat : ittookfind , ihideinlimetre . ''",
#  '@ iemonaiddibitchdawrongtreebro .',
#  '`` @ rtnba : drakenewshoereleasnike/jordan ....',
#  "ye , 'sglittershoehttp : //t.co/qctplxhexm '' .... dudefag",
#  "`` @ rachiesoul : @ dizzleofficiinnadighetto ! ! ! ''",
#  'youalonlmaoo',
#  '`` @ ramboutit : & # 8220 ; @ master11_ : @ 20tolife_ @ ramboutithoeaustin & # 8221 ; teachusaustin .',
#  '`` iteachugetcurv ?',
#  "that'siknow",
#  "`` @ reachtheeclimax : bitchcan'tcookknowsuckdick .. ''s/oon !",
#  "`` @ renegademo : fathoegetchos '' lol",
#  "`` @ riahsm : # hoesaintloy '' well'reho , oneexpectloy",
#  "`` @ rishaawilliam : @ treshon_scroog @ _nevertrusttolbitchass '' http : //t.co/amcoiny0wg",
#  "`` @ rnadjorel : bruhimtireniggaretweetinmileycyrunakebitchainttypebad '' lmaooo",
#  "`` @ sactownprodigi : justtoniromomavgamedontmeanstillbitchlmao .. fukcowgirl '' lolbitchfuck",
#  "`` @ samjlayman : holishit , freddihighmorcharlichocolfactori '' : * rollfloor , laugh *",
#  "`` @ samirahusic_ : `` in'twantsexgfifeellikei'mus .. ''-anonym '' whatafaggot",
#  "`` @ sexualgxf : @ onefollow & # 128525 ; & # 128553 ; http : //t.co/f1tjl9xnct '' @ somebodi , bitch n't",
#  "`` @ shaa_jenkin : ifyabitchalwaybitchclearlicar ! ''",
#  'orannoybitch !',
#  '`` @ shantaughth : thesecatfishhoethinkinslick ..',
#  "butniggacatch & # 128524 ; ''",
#  "`` @ shewenttojordan : can'tworribitchain'tworribout '' # real",
#  "`` @ showarr : sidehoeinsecurniggacan'thandlrealon . ''",
#  '`` @ shun_stok : & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; rt @ bluprint_4 : lmao !',
#  "thibitchcomescoottentlikefuckshit ! ''",
#  '& # 128557 ; & # 128557 ; & # 128557 ;',
#  '`` @ shun_stok : mycousinsaidsharehoebroth .',
#  "hesaidsharecarelovebroth & # 128514 ; ''",
#  "`` @ slimgirl_probz : 'mhungriionnwannaspendmoneyfood & # 128530 ; ''brokehoeproblem & # 128514 ; & # 128514 ; & # 128514 ; & # 128128 ;",
#  "`` @ smeegbabi : desehoelyinusnigga ''",
#  "`` @ snakecharmsdump : http : //t.co/4b427dqzcv '' ohyeahfuckbitch",
#  "`` @ sportscent : elimanthrewnfl-lead27thinterceptseason . ''",
#  'lmaotrash',
#  '`` @ sportscent : uscseniorrbanthonibrowncallheadcoachstevesarkisianracistquitteam .',
#  "& # 187 ; http : //t.co/joosdsubir '' 'sbitch",
#  '`` @ stellatex : guess ?',
#  'ialsozerotimemansplain !',
#  "adio ! ''",
#  'stfupussi',
#  "`` @ stephenwildboy : chill & # 128069 ; & # 8482 ; http : //t.co/mik3ipnle6 '' sexiscallilad",
#  "`` @ strap__ : iain'tsharebitchminemin & # 128175 ; ''",
#  "`` @ sukmysweet : moneyimpresssimplbrokebitch ''",
#  "`` @ sylvieamx : # piscneveranybodi'sbitch , n'tletpeoplcontrolchang . ''",
#  'rigghhht',
#  "`` @ tee_jonez : @ 16stanley @ kingcuhtukuhoidkblahblahblah '' & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` @ tee_jonez : @ kingcuh @ 16stanleyi'mmadcuhhahaha '' suur .. tukuhoita !",
#  '& # 128514 ; & # 128514 ;',
#  "`` @ tayknosbest : thesehoecrazi ''",
#  "`` @ taylorr_bab : youain'tevergonnaslicebitch . ''",
#  'kevinhart .',
#  '( :',
#  "`` @ thatniggatroy : oomffuckinfinetho & # 128553 ; dam '' @ , n'tbitch .",
#  "`` @ thegamerkingkev : iwondergirlgavehead24boydrinkmagaluftwitt '' problisendnudefag",
#  '`` @ thenewsat : # newsatquestyeahbitch , yeahbitch , call_______ : . )',
#  'maybb . )',
#  "steve-oc. ) laterd . ) jesspinkman '' @ machinegunkelli",
#  "`` @ thenymphotweet : hickithighrightpussi & gt ; & gt ; & gt ; ''itright",
#  "`` @ theonemiss_luu : wouldstilllovei'mlongeryoungbeauti ? ''",
#  '.',
#  'uglimonkeyass .',
#  "`` @ therealrickyb21 : @ jetsandaswish @ gook____y'allcomefront .",
#  "`` bitchiain'tcom",
#  "`` @ therealrickyb21 : @ jetsandaswishfaggotbitch '' http : //t.co/2hyyabk4eh",
#  "`` @ the_realist_sam : @ madrid2_yea , i'mipad .",
#  "in'tworkfriday .",
#  "let'sballfaggot @ tropicalblanket '' work2-5",
#  "`` @ theo17100 : http : //t.co/byj1hoyhmg '' scalliladwouldget",
#  "`` @ theomaxximu : # gerryshalloweenpartihttp : //t.co/3ycrsrnjhc '' halloweenyesterdaystupidnigg",
#  "`` @ theomaxximu : chrustillsupahottho '' * walkteachertest , droptestbitchfohead * http : //t.co/nb5vgdssgi",
#  "`` @ thornton25 : & # 8220 ; @ kantkeepahbytch : iloveeatpussilolinevergetfulllol & # 8221 ; ieatshitforevlol '' ever .",
#  "`` @ tmacc_gfg : & # 8220 ; @ voiceofdstreetz : `` @ tmacc_gfg : & # 8220 ; @ tizzimari : noslush & # 128549 ; & # 8221 ; hoenastianywayfam '' & # 128564 ; & # 8221 ; hoetastlikem '' & # 127815 ; & # 127815 ; & # 127868 ;",
#  "`` @ tmacc_gfg : & # 8220 ; @ tizzimari : noslush & # 128549 ; & # 8221 ; hoenastianywayfam '' & # 128564 ;",
#  "`` @ tmacc_gfg : bobbibitch-bi @ bobbyshmurdags9getlivefuck '' hellyeaplayhoeworkout",
#  "`` @ trelekidd : yobitchguccimanert @ jabarithegreat : mybitchston & # 128175 ; & # 128175 ; http : //t.co/lt9lijjpg9 '' & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` @ tweetgamelazi : iridebitchhandlbar ''",
#  "`` @ tyjoncuff : andain'thoegettraphoussseee ''",
#  "`` @ uberfact:15sadtvcharactdeath'restillbitt ... http : //t.co/ulclfuf8nchttp : //t.co/1rxyqoosm0 '' nedstarkman",
#  "`` @ unholy_jack : theseharborbitch `` partibuho '' ''lol ?",
#  "`` @ vbomb20 : @ woodchuck20pussi '' love",
#  '`` @ veronikahumbert : ultraviolvideo , comelittlbitch !',
#  "# mtvhottestlanadelreyhttp : //t.co/533flbvwqh '' bitchipromo",
#  "`` @ vineforthebyrd : onwayfuckbitchhttp : //t.co/4lmtfnl2iy '' lmfaokittycopt",
#  "`` @ wbur : asmugglerexplainhelpfighteralong `` jihadihighway '' : http : //t.co/ux4anxeawd ''",
#  "`` @ wbeezy_ : `` @ quathegreat : awwavilookcutetogeth & # 128145 ; http : //t.co/9lporcb8w0 '' & # 128128 ; & # 128128 ; & # 128128 ; ''igottagetikeavibitch ?",
#  "`` @ wbeezy_ : `` @ run_drc : itsimpl , donthoe=dontworriexpo & # 128540 ; ''fight '' ?",
#  "`` @ wannabekani : whibitchboosthttp : //t.co/uod2f5wtkv '' hersizen'texactlihealthitho",
#  '`` @ withaprettyfac : @ _1nonlykeishabetbitch !',
#  "& # 128514 ; & # 128080 ; & # 128299 ; & # 128299 ; & # 128298 ; '' & # 128514 ; & # 128514 ; kimby ! !",
#  '!',
#  "`` @ x_xpdotjdot : damnneargottaprotecttweet .. stalkerannoy '' gotdopedick .",
#  'drivebitchloco',
#  "`` @ xojennygirl : i'mmakemarackgirlfriend . ''",
#  '@ marackafayebpullinhoeliketaught',
#  "`` @ xoxo__angi : brunofagboy '' love .",
#  "`` @ yehits_von : & # 8220 ; @ run_drc : imustbitch & # 8221 ; & # 128514 ; & # 128514 ; & # 128514 ; sikenaw '' thialwaybeef & # 128514 ;",
#  "`` @ yank : down6-1 , # yankelookrallibottom9th . ''",
#  '# rallycap',
#  "`` @ youngricooo : & # 8220 ; @ wexicanafro702 : don'ttakeadvantagniceperson & # 8221 ; @ hoe '' @ everyjuan",
#  "`` @ youngricooo : happibirthdaybitchnigga @ wexicanafro702 '' thankpal",
#  "`` @ youngricooo : sadknowhoewon'tfuckbcain'tgotstack . ''",
#  'waittillfriday',
#  "`` @ yungmigo : @ shane_a1cincoshitharderfuccnigga '' yeefuccwitrichhomicuzdatyahomeboyfuccnicca",
#  '`` @ zoebarton3 : @ h0rheydewwwisaidthatlastsunday .. lastsundayi .',
#  "readnig '' & # 128563 ; & # 128563 ; & # 128563 ; & # 128563 ; & # 128563 ;",
#  "`` @ _bada_b : ipunchrealniggafacecauspussiniggagonnapunchrightback '' strongmushshak ..",
#  "`` @ _beedontcarmypussistillfresh '' & lt ; -- -- -somethstankgirlsay .",
#  '`` @ _geewillikers_ : assslaponegreatestth .',
#  'haha .',
#  "& # 128527 ; ''islapgirlass .",
#  '.',
#  'shegotmadiaintgetpussiweek',
#  "`` @ _tommycollin : @ wearerichnow @ buffalobilyeahtexanmuchbetterfuckretard '' isee'remad .",
#  '`` @ __malibubarbi : ndwtfdarkbitchblond ..',
#  "pleashaveseverseatho ! ''",
#  '.. looklikeblack & amp ; mild',
#  "`` @ __sugga : there'slanebitchneedstay & # 128526 ; ''leftngetrightfuckouttafac & # 128557 ; & # 128129 ; & # 128536 ;",
#  "`` @ __sneakyb : ihateboydenibitch & # 128080 ; & # 128553 ; ''smh",
#  "`` @ __taradise__ : yanigstillsayy'alln'teatbutt ? ! ''",
#  'withastraightfac !',
#  "`` @ __yourewelcom : imbossassbitch '' ... needsitcorn",
#  "`` @ _iwantfranni : he'sho , ica n't ''",
#  "`` @ _prettyflvck0 : meandpaulthinkinboutgettinrentalfordaweekend & # 128665 ; & # 128168 ; & # 128168 ; ''ooohshitbitchbettastaydastreet",
#  "`` @ _rapdream : bitchholdniggagetlock ... niggagocollegmilitari'sdifferstori .",
#  "& # 128564 ; ''",
#  "`` @ _simplycaitlin : friendhat '' ratchetho ..",
#  "`` @ adriwadrri : nolovefucknigga '' hoe *",
#  "`` @ airmaxlad1 : hotmeathttp : //t.co/brz8imk5vk '' sexifuckscallilad .",
#  'iwouldlovemeettrain .',
#  "`` @ airmaxlad1 : sniffhttp : //t.co/fhhbbrmybn '' pervscallilad .",
#  'fuckyeah .',
#  "`` @ alejandra_p13 : thesebitchlovesosa ''",
#  "`` @ alexissixela__ : & # 8220 ; @ white_thunduh : ilegitwatch3040second & # 128529 ; & # 8221 ; sodidiwtf '' probcausretardsmh",
#  "`` @ allisonnamaya_ : whatinamecat , idea ? ''",
#  'mrpussi',
#  "`` @ altosteel115 : http : //t.co/tm28mh5xg2 '' woofwoof .",
#  'sexithugboysc .',
#  '`` @ ambitiousbr : @ _1nonlykeishauseedamnphon ?',
#  "& # 128547 ; & # 128530 ; & # 128542 ; ''marribitchmakedemand ! ! ! !",
#  "youn'tcal",
#  "`` @ analicialoui : tevinfavoritsophomorithink'sfunni '' hereal .",
#  'lmaoohelittlho',
#  "`` @ angelenagoley:10sexposithttp : //t.co/nt3pabmwsmhttp : //t.co/jmhz8sczf0 '' nawucallfucksoulouttabitch & # 128557 ;",
#  "`` @ ashlingwild : @ itsnotadamboresupposcut , faggot ? ''",
#  'sometim',
#  "`` @ ayyee_ceee_ : onemantrash & # 128686 ; anothmantreasur & # 127942 ; ''",
#  "`` @ babineaux_ : in'tgottyp .",
#  "badbitchthingilik '' * iongotnotyp",
#  "`` @ bigbootybishopp : @ white_thunduhlassencc , coachwant '' feelyoullgetnigdoubt",
#  "`` @ bleedingtrap : godteeth , goldchainwhitebitch , cocain ''",
#  "`` @ cheetahbluntz_ : itho , hoe & # 128129 ; ''shhhhh",
#  "`` @ chieflottaho : ind.c. , callrol , chiraqcallthot . ''",
#  'allacrossamericaknownho .',
#  "`` @ clayton_jenn99 : i'mgonnamissbitchbudriv ... ''wo n't .",
#  "don'tli",
#  '`` @ coltforty2gon : hatebitchtriputfriendzon .',
#  "bitchi'mtryinscoreputendzon & # 128293 ; & # 128293 ; & # 128293 ; ''on .",
#  '.',
#  'soul !',
#  "`` @ complex_uk : ashleyyoungtridenibird * * * landmouth -- - & gt ; http : //t.co/mlr5ewgonkhttp : //t.co/avchfj7rem '' hahaha",
#  "`` @ datfullerkid : @ trevaughnlgyallgimp ? ? ''",
#  "ain'tthtbitchhuhlol",
#  "`` @ deepthroatmik : `` @ boys_south : takerid & # 128525 ; & # 128139 ; http : //t.co/h5matjyfga '' # redneck '' woofwoof",
#  "`` @ demi_eggleton : ohgodilovevictoriamitchel '' bitchlov",
#  "`` @ djsliim : thatlongdistancshitwackiknewbitchcheat '' -uhoh",
#  "`` @ fiirt : he'sdoitright & # 128525 ; & # 128120 ; & # 128158 ; http : //t.co/jzkkivuvjc '' bitchsmh",
#  "`` @ fatboyswagg347 : bandatpussilif & amp ; gottapay2.5millondollarfin ''",
#  "`` @ fuckcamoclark : roseredvioletblueniggerblack , know'stru . ''",
#  '@ dylan72892',
#  '`` @ g0rillaz0 : sitwindowsil , windowopen , birdtrifli .',
#  'smack .',
#  "# protecttheanim '' @ peta",
#  "`` @ glowstruck : butniggagonnigga , nigga . ''",
#  'yousoundfuckinretard',
#  '`` @ greggutfeld : videoentirmedialikemock .',
#  "http : //t.co/xfr1crxwsm '' crybabi",
#  "`` @ gurl_im_angi : @ itskiaraaaa @ westyourmajestii'mevenshistfu '' kikimom : hiangeliquangeliqu : smile * dipcrackersoup *",
#  '`` @ haitian__gold : timtebowgotcuteveriteamnflalreadigothoestarkvil .',
#  "smh . ''",
#  '& # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;',
#  "`` @ hazelebabi : karmabitch # damn # godprotectshisangel & # 128588 ; '' * siptea *",
#  "`` @ hornyjhb : fuckinhotgympussihttp : //t.co/zvymcxquta '' fuckyeah",
#  "`` @ hxhassan : jihadipatronhajjajal-ajmiarrestkuwaitairporthttp : //t.co/zmlokfwdql ''",
#  "`` @ iampickuplin : youcallfiremancausiturnho . ''",
#  "`` @ icrawley : icouldneverbbilildickthtigotabortlastbitch '' -ohmygod",
#  "`` @ idntwearcondom : watchwomentriargulikedickactualfuckpussi '' ihatebitch",
#  "`` @ ilgdaili : andsmokeweedpubl , fuckcopman , wan na , n't , runcom '' retard ?",
#  "`` @ itrapwatermelon : tweetibirdtho & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; http : //t.co/jbnonm3n1p ''",
#  "`` @ irlfatti : pussisweetlikewatermelonhttp : //t.co/sklph3ttog '' thotermelon",
#  "`` @ itscoleharmon_ : whentwitterrapperdmtrashlinkhttp : //t.co/35nmr4auqg ''",
#  "`` @ jsadass : loudbitchannoy ''",
#  "`` @ jacaxeltlu : eventueveribitchturnho . ''",
#  '# truuu',
#  "`` @ jaimescudi_ : `` @ tonybthrz_ : `` @ jaimescudi_ : iswearoomftritalktomorrow .. '' @ '' @ barackobama '' pussi",
#  "`` @ jama_jam : youbitchpretendtfcrazi .. ''youain'tneverli ...",
#  "`` @ jasmyncyniqu : @ white_thunduhkbyeho '' umby ..",
#  "`` @ jayswaggkillah : jackiretard # blondeproblem '' atleastimakegrillche !",
#  "`` @ jboii2 : imakeepgivepussiassniggaahreasonh ! ''",
#  "`` @ jethromass : photo : http : //t.co/cxrs5bvhpw '' soleheaven",
#  "`` @ jgabsss : staceydash & # 128166 ; http : //t.co/pdlg46rjol '' baddestbitchevaaaa",
#  "`` @ juicyyyjayyyi : sidebitchsunday & # 128514 ; & # 128514 ; & # 128514 ; '' & # 128514 ; & # 128514 ; & # 128514 ;",
#  '`` @ k_eazy26 : factbaldheadbitchmadeshit .',
#  "& # 128074 ; & # 128074 ; & # 128555 ; & # 128530 ; http : //t.co/fdyojpt9xg '' lmao & # 128553 ; & # 128514 ;",
#  "`` @ kayreneeee_ : fuckwitustweakinho '' shmurda !",
#  "`` @ kazooook : weactinlike's7thday @ wesgodlaflarhttp : //t.co/s9gmtevpat '' & # 128123 ; spook",
#  "`` @ kikistfu : i'llbreaklilbitchneckwon'tevenfeelsorri '' savag",
#  '`` @ leikant : thifuckhot ! !',
#  "# scalli # sneakersex # sockfetish # sniff # trainersexhttp : //t.co/tubivxbxco '' lovekinkisc",
#  "`` @ likemicah : y'alldumbassniggapressho .",
#  "y'allweakfuckfuck '' ... weedho , oreo .",
#  "`` @ lildurk_ : iturnyobitcheaterrrrrrrrr ''",
#  "`` @ lildurk_ : in'ttrustdesehoenikkitold51stistayfanscreenshotasap '' finnacomechiraqshootsumn",
#  "`` @ marackaf : & # 8220 ; @ white_thunduh : ayeyallimatryoutbowlteamfrfr & # 8221 ; tryoutpasstho '' theretworetard",
#  '`` @ maybe6789 : nowugotuwantbitch !',
#  "enjoyhttp : //t.co/glqzwtgmj9 '' crazipartiiwouldloveattend .",
#  '`` @ metroadlib : colorcontactey ?',
#  'blindermin .',
#  "causcan'tse . ''",
#  'lmao',
#  "`` @ michelle_westt : fact `` @ poonsoak : onlidudehoesayn'tgotho & # 8221 ; '' @ j_austin12",
#  "`` @ midywidey_ : i'mreastartsmackbitchperiod ! ''",
#  'bluffinbest',
#  "`` @ molssyo : lifebitch , diethatgethigh , causnevaknow'regonnago '' sisterperfect ( :",
#  "`` @ molssyo : oneusdrug , 'restillwrong & # 128514 ; @ currieburri '' hahahahahahahimbitchsometim ( :",
#  "`` @ morgandayl : i'mfeelprettifuckinghetto '' smh",
#  "`` @ nohands_24 : `` @ 20tolife_ : `` @ nohands_24 : `` @ dejaaleeann_ : @ b_coleman2sweari 'm # 1man '' easili '' easili '' behindaustin '' nip ?",
#  "`` @ obey_jrock__ : thitrueridediebitch & # 128175 ; http : //t.co/bkwhx83fkw '' fuckhahahahah",
#  "`` @ oldpicsarch : h.g.wellcharlichaplinhttp : //t.co/stiddhk3wt '' # histori # photographi",
#  "`` @ ortiz_jaylen : alliseebruno'sbitchasstwitt .",
#  "wtf '' bruno'sse ( drakevo )",
#  "`` @ ozzie_garza : @ white_thunduhi'mcoolfaggotchil '' tfcoolnigga",
#  "`` @ ozzie_garza : @ white_thunduhi'msurebitch '' frfrtf",
#  "`` @ poppunksuck : twittersourcnewsbroadcastfuckretard '' nbc , abc , cnn , fox , etckeepquiet .",
#  "`` @ queendulaaa : gotcouplbitchsayknowbuti & # 8217 ; letmoneytalk & # 128526 ; & # 128076 ; ''andi'mlik ... # wwyd",
#  "`` @ realfort : grudgweirdo '' bitch",
#  "`` @ rhythmixx_ : itoldmariamcigarettbirthday '' youalsocalltrashrn",
#  "`` @ riananewman : @ 22edhambrownitonight '' kind ? ! ?",
#  '!',
#  '`` @ rollyup23 : notextback ?',
#  "in'tgivefuck , i'lltextanothbitch '' damnsomeonhurtlol",
#  "`` @ ronald_iongi : ummmmmmokayhttp : //t.co/4bvlsci5k5 '' gothoeleftright & # 128514 ; & # 128514 ; yahthang !",
#  "`` @ royalswagg_ : usey=mx+bfindslopeass ''",
#  '`` @ rugbysocklad : fitlad !',
#  'nicegear !',
#  "http : //t.co/thnxx1lc1m '' scalliladntrainerwouldget",
#  '`` @ rugbysocklad : hellyeahbro !',
#  "http : //t.co/9yib45ud6c '' fuckyeahsexiscalliladhotgear",
#  '`` @ rugbysocklad : helpmat ! !',
#  "http : //t.co/emnado1qoj '' ilovescalliplay .",
#  'fuckyeah',
#  '`` @ rugbysocklad : ladlad !',
#  "http : //t.co/f3ujcyj4of '' fuckyeah .",
#  'ilovescalliladact .',
#  'hottrain .',
#  "`` @ savage_twoton : nextyearbitchgonnalikegottapromiswon'texpo & # 128514 ; & # 128514 ; & # 128557 ; ''",
#  '`` @ scallynikelad : & # 8220 ; @ sleazytwink : sohot ! !',
#  "rt @ opcinjen : lick , bitchhttp : //t.co/jloukqdcom & # 8221 ; ''fuckyeah .",
#  'eattrainerudirtifuck',
#  "`` @ sierrabernia : & # 8220 ; @ t2g_cincokilbi : y'allthinkcelebrpussidifferloc ?",
#  "& # 128514 ; & # 8221 ; yeahmeghangood ''",
#  "`` @ sleepy_yongguk : `` isawajummawalkbeginsay , 'wow , trashican'tevenlisten .. ' '' & # 128514 ; ''lmaoo",
#  "`` @ sniffsockslad : needsoxhttp : //t.co/xydb1rchxh '' fuckyeah .",
#  'ilovekinkiscalliladw/ranksoxsneak',
#  "`` @ snoleezey801 : in'teverexposfemallik .. that'schildish .. ''bitchniggashiiii .....",
#  "`` @ socass_ : `` @ 00sexilexi00 : @ socass_yasss '' * trinewthingbestfriend * '' * bitchlov *",
#  '`` @ socass_ : duderemembwopvideo ?',
#  "@ 00sexilexi00http : //t.co/p3heuboqbu '' omgwheredidyoufindthat",
#  "`` @ soxandjox : thickrawfuckhttp : //t.co/g8rvuhcebn '' damnmanpussigetworkout .",
#  '`` @ soxdawg : rawr ! !',
#  "rt @ skinrubberboi : `` '' sexifrenchsc .",
#  'ilov !',
#  "# frenchscalhttp : //t.co/5idq3r5akz '' sexiscalliwoofwoof",
#  '`` @ splurgb_ : nothinlifefre ..',
#  "somebitchneedwriteyapanti '' & # 128557 ; & # 128514 ;",
#  "`` @ stephencdo : @ currieburrionebitchwantburritoucatchpotosino '' huh ?",
#  'haha',
#  "`` @ talibanshawtyy : niggawholehoecuz '' couldn'tsaidbett .. & # 128588 ;",
#  '`` @ theaveragerock : hardcorwayeatmacchees1 .',
#  'boilwater2 .',
#  'snortcheespowder3 .',
#  'drinkboilwater4 .',
#  "fuckbitch ''",
#  "`` @ thebravebird : # yourenotmytypfadeperpetufresh . ''",
#  "that'srealassbitchrit",
#  "`` @ thejudyann : annoybitchilovehttp : //t.co/8oxlqvqbrc '' judyann'ssopretti ! ! ! !",
#  '!',
#  "`` @ thotmouth : http : //t.co/aqkgorauxx '' lmaobitchgothuggi",
#  "`` @ trestiff : hibitchnobitchbyebitch '' http : //t.co/rbcrxmrtqp",
#  "`` @ trutherbot : looklikebitch ? ''",
#  '@ el_capacitor',
#  "`` @ whoiscoreyk : chasemoney & # 128176 ; & # 128581 ; hoe & # 128111 ; & # 128175 ; & # 128175 ; '' & # 58399 ; & # 58399 ; & # 58399 ; & # 58399 ;",
#  "`` @ whooligan__ : can'tstand `` in'tknowiw '' assnigga & # 128564 ; ''bitch *",
#  "`` @ wiganzlad : `` @ markycrumb : `` @ gmail_short : i'mwayhttp : //t.co/mqczuxlbtt '' love # chav '' hot '' sexiscallifuck .",
#  "`` @ witmyrudeass : thesenewligaybitchn'tknoshitwork ''",
#  "`` @ witmyrudeass : whenbitchn'twantrealjobbecomstripperlol '' lol .",
#  "`` @ wodaeeex3 : awwwmeatmeatinhifeelin '' ainnnfeelbitch",
#  "`` @ wodaeeex3 : iwantsnakebit , myindustripiercin & amp ; atattoo '' demhoeaccessoridea & # 128064 ; & # 128064 ; & # 128056 ; & # 9749 ;",
#  "`` @ worldtravei : babialbino & # 128034 ; http : //t.co/2tytqj3fec '' @ meeeesh1395",
#  "`` @ worldwarzee_ : hoeain'tloy . ''",
#  "`` @ xoxoclauudia : yassssss , orderchin & # 128079 ; ''bitchatetacofatfuck",
#  '`` @ z0mbiedanc : imadebitchlunch .',
#  "@ elizabethbatman '' bitchlovelunch .",
#  "`` anobrain '' butsoonbitchgetrichpolitpow , viewchang !",
#  'politwhor !',
#  'http : //t.co/ekepsjwcyu & # 8221 ;',
#  "`` apussidaykeepdevilaway '' - @ doperthanyola",
#  "`` ain'tbitch '' ... whatmean ?",
#  "`` allbitchwantbabi , in'twantchildren . ''",
#  "`` andbitchmustlost '' & # 128514 ; & # 128514 ;",
#  "`` babiilikeleftsid '' bitchcan'tcuzstreetsidetwittersaidiain'tr",
#  "`` bae '' soundlikeghettoword .",
#  'usesomethel',
#  "`` batterweecuntjewi '' cofuckex ?",
#  "emmaisntbattergirli'venail ? ivemov , stoppussinurself .",
#  "`` bleedho ! ! ! ''",
#  '-alexa',
#  "`` boolin'bandowitbitch ''",
#  "`` brownibrowni '' ilovemovi .",
#  '& # 128517 ;',
#  "`` butineedbadbitch'shott '' mightrealistshitpartynextdooreversaid .",
#  "that'sifeelineveryday",
#  "`` bywaypunchbitch . ''",
#  "`` caesarhom '' rt @ naewoodst : & # 8220 ; @ mjayskillz : http : //t.co/mw5kaojkxb '' theremuchbitchlooklik .",
#  "letstartapeshit & # 8221 ; & # 128557 ; & # 128557 ; ''",
#  "`` chinesmaverick : wecommuncomrad , uknowgiveimperialistyankbirdi '' http : //t.co/38gz1jerp",
#  "`` dadsayhisnapchat '' dad `` & # 9996 ; & # 65039 ; & # 9996 ; & # 65039 ; ducebitch '' & # 128514 ; & # 128514 ; & # 128553 ; & # 128553 ;",
#  "`` dobelievhoefactloy ? ''",
#  "`` idisagr , ibelievfactloyalestbunch , hoe ''",
#  "`` don'tknowuglibitch !",
#  "don'tknowbrokenigga ! ''",
#  '-- @ kevin_g',
#  "`` don'tmakemakefallliveniggalikemee ... ''thebird1 & amp ; 2favoritsongweeknd",
#  "`` don'tworriniggase , worriniggadon'tse ... dat'sdaniggafuckinyobitch . ''",
#  "`` don'tevergivepussiaway .",
#  "youkeeptight , alright ? ''",
#  "`` dropstackcausbitchi'mon '' .",
#  "- @ 1poloboysongcal `` dope '' .",
#  'downloadmixtap : http : //t.co/lacz1e6tg7',
#  "`` dumbbitchdumbth ''",
#  "`` eatpussilikerealniggahungri ''",
#  '`` eff .',
#  "let'sgocrippl . ''",
#  'http : //t.co/ksamx1jpfv',
#  "`` everythlookbetterbitchnext ''",
#  '`` facto @ shaunasayomi : whocarehoeasslooklik ?',
#  "http : //t.co/cjdt987aqf ''",
#  "`` foreveribadbitchniggatirefuck ''",
#  "`` foreignchick , lie .. manbitchbeauti ''",
#  "`` freshniggaknoineedcleanbitch ... whoknoi'mworkcuziwannaseeteamrich . ''",
#  'http : //t.co/cgx3hnak9a',
#  '`` fuck5/0imakerul .',
#  "suckdragonballbitchcallgoku ''",
#  "`` generasciiboxnodej '' iseeabilbringflappy-birdnodeviaasciitubebird^_^http : //t.co/lrjwdfhv7t",
#  "`` getshitbitchfinebear ''",
#  "`` getassbackdetroityafuckin'wigg ! ''",
#  "`` girlid , okayiain'tmadyo , unlessstabheart , loveho ''",
#  "`` howdoyouknowmytwitterpassword '' bitchplea",
#  '`` haveseenshow ?',
#  'haveseenho ?',
#  "ifin'thotwouldthick ? ''",
#  "`` hebitchhitho '' & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` hemarriwhitewoman ... luckisum-bitch '' -unclrucku",
#  "`` hewannanigga , i'mtrinnasaveaccount & # 128553 ; '' & # 128514 ; & # 128557 ; & # 128514 ; & # 128557 ; omgimmafunniassbitchman , 'srealshit & # 128175 ;",
#  "`` hergreatgrandmaho , grandmaho , momho , 'shoe !",
#  "it'slonglineho ! ''",
#  '-grandpacarleveryon',
#  "`` heygolookvideomanfoundkidnapgirlohio ........ nigger '' - # shitmybosssay",
#  "`` heypussistil ? ''",
#  '`` howdraftgung-hofolksendafghanistanwarzoneshow ... http : //t.co/sr1zcehx',
#  "`` howhott ? ''",
#  "`` abitch . ''",
#  "`` howutalkhoeboutbronem .. whitalkhoeboutbronem ''",
#  "`` , crazibitch ? ''",
#  'hilari !',
#  '`` iknowshoedirtifuck , whatev , bitch .',
#  "youn'tcal ! ''",
#  'like , negro ... onefirstthinglooksho , dog',
#  "`` ithrillbilli .. hillbilliheart . ''",
#  '- @ billyraycyru .',
#  'hahahahahajesumurphi !',
#  "`` icallbitch '' @ makennam_",
#  "`` ican'thandlliquor ...",
#  "butbitchcan'thandlmeeedd '' -chiefsosa",
#  "`` in'tchasedud ...",
#  "ichasebitch . ''",
#  '-edgarbautista',
#  "`` in'tloveho , babiit'sforev ''",
#  "`` idontevenneedpicturtamar , bitchbeateveripictur '' & # 128514 ; & # 128557 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` idontho '' & # 128564 ;",
#  "`` ifoundnewwaychugopenmouthalot '' # shitallysay",
#  "`` ifuckhatebitchmuchiwannasmackfacetongukiss ''",
#  "`` igotbitchsetlikejadapicket .. queenlatifahrideroundniecbitcht ''",
#  "`` igotsist , toldstopcallwomenbitch .. ''",
#  "`` iguessnightbitchdi ... ! ! ! ! ''",
#  'stewinigga ... !',
#  "`` ibitchbitch , bitcheathalibut .. ''- @ iamyoungroc # freshrhym # jerksquad # slowstir",
#  "`` ilady-lovshe'smarri , istillwannabangshewon'tsexwhatbitch '' ~atroubadour , probabl",
#  "`` iheardlookcandiman , bitch ''",
#  "`` ihopen'tgetmad , ladi .",
#  "icallbitch'bitch'bcin'tknownameindividu . ''",
#  '-kattwilliam @ letmicahdown',
#  "`` igotnumber3i'mbitchboy ''",
#  '`` iknowshiteatingrin !',
#  'youeitherfuckgirldreamsoldcar .',
#  "weknow'refaggot .",
#  "what'dsel ?",
#  '`` & # 128514 ;',
#  "`` ioldermencaus'rematur '' thatsupposfoolusbitch ?",
#  "`` iprollileavbitchcuphandyohandhand . ''",
#  "`` isaidn'tlik , tastlikewolfpussi '' '' ?",
#  "howevenknowtastlik ''",
#  "`` itaughteatpussi , cuthair '' ''itaughteatpussihair '' & # 128514 ; namemovi & # 128514 ;",
#  "`` iusedresslikecop . ''",
#  "`` ohreal ? ''",
#  "`` yeah ... right9/11 ... madpussi . ''",
#  "`` realli ? ''",
#  "`` ye ... i'llneverforget . ''",
#  "`` iwentjailflock , & amp ; camehomewitstrik .. youwentjailbitch , camehomedik '' - @ yg",
#  "`` ifuckuustand '' .",
#  "`` udizzibitch '' .",
#  'twouniqu & amp ; separphraseioverheardrelsayiyoung .',
#  "`` iwokelikethi- '' bitchgobackb",
#  "`` iwouldrathercallbitchsir '' -mimanag",
#  "`` i'llbeatpussihard ''",
#  "`` i'llslitthroat-neck '' http : //t.co/chffsdeddd",
#  "`` i'mfunkiasshonkey . ''",
#  "- @ jtimberlak'sshout @ macklemortonight `` cabaret '' & # 128514 ; # jt2020tour",
#  "`` i'mcomparkfcpussi '' @ maxon_maxoff5",
#  "`` i'mdownloadnewpersonordernewfac !",
#  'youbitch ..',
#  "ilov .. goddamn ! ''",
#  '-axlroseyellsexrobot',
#  "`` i'mfeelinlikemalcolmmiddl , bitchsurroundcan'tmissem ''",
#  "`` i'mgonnapissdimpl @ soni99a_ : stopwastprayertrashteamlol ''",
#  "`` i'mprobablmainbitchchocoldipcinnamonappl ''",
#  "`` i'msickshitman @ jonniesantana : sitbitchass , i'mfedbrort `` @ 80sbaby4lif : genothrewyetanothpicksmh '' ''",
#  "`` i'msorriifuckyobitch ...",
#  "butreallidignigga '' @ kingl",
#  "`` ib '' irritbitchsyndrom .",
#  "`` iflovehideyobitch'llkeepshorti . ''",
#  '@ wizkhalifa',
#  "`` iftalkbackain'tgetpussi . ''",
#  ': http : //t.co/vgnwcfgvsj',
#  "`` if'rebadbitchputhandhigh '' everigirlroomstartwavehandaround .",
#  "`` immatiebitchbasementdonkey-fuckasstwoweekstraight '' hahahahahahahahaha # 50centmovi # beforeiselfdestruct",
#  "`` inmymind '' gottadumbhoeanthem ...",
#  "`` isalbinomexican ? ''",
#  "`` nodad , 'sasian . ''",
#  "`` ittaketruedirectionacceptlarri '' youknowbitchfanlikemakeboycri .",
#  '# thankyoupaulforconfirminglarri',
#  "`` it'salleg , ubedroom ?",
#  "diduse ? ''",
#  'wordnaiv & amp ; blindbitch .',
#  'weknowurhusbandcheatu.ramonadumb ! !',
#  '!',
#  "`` it'sneverlatetagbitch .",
#  '`` - @ cyfyr',
#  "`` it'sdyk '' -hunterdykedykehttp : //t.co/lgtw3awmeh",
#  "`` juliarobert , 'reho '' @ laurengardner8 # nottinghil",
#  "`` justfollowyellowbricktwitt . ''",
#  '`` lmfaoooooooooooooooooo @ bb_brook : ifpussigoodmama & # 8217 ; like ?',
#  "guessgottago & # 8230 ; & # 8230 ; & # 8230 ; .. mama . ''",
#  "`` lol , crippl ! ''",
#  '-wendidavi .',
#  'rt @ mailonlin : scientistcreatremote-controlchickstudishipenguinhttp : //t.co/mt3b09slod',
#  "`` let'snipahoyspankmayb ''",
#  "`` let'skillcrackerbabi ! `` .",
#  'wtfihear ? ? ? ? ? ? ? ?',
#  'wow .',
#  "`` like ... correcti'mwrong ...",
#  "doen'tpimpininvolv'smackinbitchmoney ' ? ''",
#  "`` lmao @ blackbeauty515 : & # 128514 ; & # 128514 ; rt @ 80sbaby4lif : poundcakelooklikepussi & # 128514 ; http : //t.co/ufywcc9xci ''",
#  "`` lmao @ swilla_lo : thed.roseadidalighterphon .... shitretard ''",
#  "`` mam , ren & # 233 ; edoethaarrolnetzeongesteldwatongesteld ? ''",
#  'vandatsoortvragenwaarjedenkt : hoelegikdieweeruit .',
#  "`` maybwantfriendmayb'sstupidbitch .",
#  "youneverknowmakecum . ''",
#  '& # 128514 ; & # 128514 ; & # 128514 ;',
#  '`` mineplaydmxkirkfranklinsmh @ _justcallmebrit : wellneighborghetto .',
#  "theygetlike5ambeatkid . ''",
#  "`` mygrandmausecallporchmonkeytim ... comethinkreferbrokenbottlniggerknif '' & # 128563 ;",
#  "`` mymommatoldtellmindyoooodamnmothafuckinbusi2+2knowinbitch ! ! ! ! ! ! ''",
#  "`` mynipfreeeeez ... 'sokay'reslicebra .... '' & # 128514 ;",
#  "`` mytwitterhack '' =i'mpussiadmitisaidiwantactlikeineversaid .",
#  "`` nahgirliain'tgonablmak , 'stightsincrusslossjob '' backlik `` damnbitchr ''",
#  "`` nahyou @ nomeek_justmilz : & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; yothoughtsome1photoshopfacefaggotsmmfh ... hateyal '' http : //t.co/5e2fkq3q2t",
#  "`` newflam '' songyrlolbitchsuperrunlik",
#  "`` niggaalwayyel `` fuckbitch , getmoney '' meanwhil'rebrokestillwantbitch & # 8230 ; . ''",
#  "`` niggapresspussi , eeeeeennothin ''",
#  '`` nobitch `` -nan',
#  "`` noboathoepleasthank '' -mom",
#  "`` ovo '' & # 8220 ; @ allthingsfresh3 : & amp ; kendricklamarstilltrash & # 8221 ;",
#  '`` ontop , pregnantasssorriho .',
#  'aintnevergotmoney .',
#  "evenwaterbrok . ''",
#  '- @ talltrappin88 # riptallt',
#  "`` onlicouplredsoxgottenpastfirstbas . ''",
#  "i'mdielaugh .",
#  'maybyankneedteachgam .',
#  "`` ourpeopl '' .",
#  'nowtimearyanrace2standsay `` `` .',
#  'beformongerlturnworldghettoslum .',
#  '1488',
#  "`` pistolwhipdickau , shootyobitchclub . ''",
#  'sometimfreestylfreestyl .',
#  "andi'mokay .",
#  '`` rt .',
#  "pleasthank @ bmorepocahonta : didpiercpussicomeacrosstimelin & # 128528 ; ''",
#  "`` remimachiavellisendshotyabelli '' & # 128553 ; bitch & # 9994 ;",
#  "`` robertoonenastiho ''",
#  "`` sorrijbfan & # 65292 ; reallijustincomeback '' .",
#  'thattopcommentjustintimberlakvideo10millionview .',
#  'sonfuckbitch !',
#  "`` search '' incredstori1whiteman'squestfindingredinecessarimakecaribbeanjerkchickenredneckland",
#  "`` sellsoulmateriwish : fastcarbitch '' # tupac # smile # remix",
#  "`` shakebear ... akatworednecksexdeadbear ''",
#  '`` shallicompartheesumm & # 8217 ; day ?',
#  ", summer & # 8217 ; daybitch . ''",
#  "`` shegottashapepussiliptho @ postprettypussi : wholewheatorganpussihttp : //t.co/kq0r0a7z2g ''",
#  "`` shesaidwiggamanrich ... takedu-rag '' http : //t.co/jb7j3zsbam",
#  "`` shebitchanyway ''",
#  "`` she'sflorida'vegotsnifftestswamppussi '' & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128553 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` slowfuck , bitch , iknowl ! ''",
#  'classiyoungladi .',
#  "`` so'sgoodfootbalplay ... stillactlikenig ''",
#  "`` stoppussi , son , shoveneedlheart ! ''",
#  '# afterearth',
#  "`` stoplookusgoeatpussi , yuppifuck . ''",
#  "`` takinstraightdirt , fingerpussiiknowiputdick ? ''",
#  '@ xernee18',
#  "`` thatain'tbromov , 'shoemov ''",
#  "`` thatgirlplainlookborderlinugli & amp ; chunki '' .",
#  "heyleast'sgotnicesmil & amp ; greatperson .",
#  "`` thedevilgrowinsidheartselfishwickwhit , brown , yellowblackcolorrestrict ''",
#  "`` thewatern'tyellow , i'mhealthistud ''",
#  "`` thesehoeain'tloy ''",
#  "`` thesehoekeepcalliniain'tpickin '' & # 127926 ; & # 127926 ;",
#  "`` thesesourapplbitterbitch , i'mfuckinwitem ''",
#  "`` theyfaggot @ jonniesantana : oriolpettifuck ... gotsweptouttabitch ''",
#  "`` theyghettoassband '' * getsnuck * & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  '`` .',
#  "thatdivistrash @ nomeek_justmilz : saintgonwinnfcsouth ... watch ''",
#  '`` thifanwait , bitchniggahate/oldhoed , lookmama , & # 8230 ; http : //t.co/snry6a7vyb',
#  "`` thighettomotherfuck '' -missielliott",
#  '`` thirecipcallleftovbrowni .',
#  'whathellleftovbrowni ?',
#  "that'sbrownin'teatenyet .",
#  '`` - @ ericanadine26',
#  "`` thoseratchetbroadn'trepresyourwhiteasscan'ttalktrash'causracistshit '' black",
#  "`` trustnonee , bitchi n't ``",
#  "`` twittertwitt '' bitchtwitterlif",
#  "`` tworoaddivergyellowwood , ichoseonej & # 246 ; tunheimr '' -robertfrostgi",
#  "`` ugot200kbitchnigga '' -- alhaymonantoniotarv",
#  '`` uh-uh , ?',
#  'youremptiheart , emptibottl , yellowcab .. thatwouldlikecatchcuzyolatestexmadeumad ..',
#  '`` usegirlfriend , igotho ..',
#  "ilookingoodgirl , fuckinlow . ''",
#  '`` virginpussi `` ( ) `` , regularpussi `` ( ) `` , oomfpussi ( _________________________ )',
#  '`` whaaaaaat !',
#  'lmaooo ! ! !',
#  "@ cromotoast : @ creepgoddess'siluvufatbitchcuzy'allgotbigoletittiphatbooti ''",
#  "`` walkbitchlik , niggawemadeit ! ''",
#  "`` wehatenigg , hatefaggothatesp '' -kkkralli",
#  "`` 're , 'requeer ! ''",
#  '`` 2,4,6 , hut !',
#  "welikebutt ! ''",
#  "`` wellbitch , biologsaid ... '' & # 128514 ; & # 128514 ; & # 128514 ;",
#  '`` whati ?',
#  "@ betysweetcock : gottareportspamrt @ 80sbaby4lif : ladirtheadgamebetterpussi ''",
#  "`` whenimdonehoepasssquad '' g ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !",
#  '!',
#  "`` whofuckcallinjiggaboo , nigga ? ! ''",
#  '`` whipeoplthinkgaymarriagokaybeyond .',
#  "sorriin'twantfutursonsee2fagwalkstreetholdhand",
#  "`` whiulittlbitchchriain'tsixbitch '' -allisonmom",
#  "`` whiwouldiwantplaypussi ? ''",
#  '- @ jimmyfallon * dead * # snl',
#  '`` whiwouldwannagreenrang ?',
#  "he'sevil ! ''",
#  'duhbitch',
#  '`` whiwouldwantpussisideburn ? ..',
#  "thatgoodquest '' @ _hy0unghahahahaha & # 128514 ;",
#  "`` willshankbitchcevich ''",
#  "`` work '' - @ tydollasigngetroughdayhahaha # hoe",
#  "`` wowbitch '' ye'salreadiestablish , anythelssay ?",
#  "`` y'allforgetbrandnewbabigirlhom '' bitchcookiburn",
#  "`` yah '' saidwordmtzra'ym ( egyptian ) peoplysrah'alinheritkushit ( ethiopian ) .....",
#  '`` yaoooooooo @ yea_im_jamaican : mawninyardi !',
#  "& # 128154 ; & # 128155 ; & # 128536 ; ''",
#  '`` yobitchhorn .',
#  "trynashootporn . ''",
#  "- @ kinglthat'stshirtworthitoni",
#  "`` yoisubletpussi '' # shitfahdsay",
#  "`` yofeetsmelllikepuss '' & # 128514 ; & # 128557 ; whut ?",
#  "`` likeflowerbitch '' & # 128514 ; & # 128557 ; & # 9995 ; & # 128553 ; omg",
#  "`` yomama , bitch . ''",
#  'rt @ theacetjshow : whatonesentencendrelationship ?',
#  "`` youain'tgunnashitspearchuck ''",
#  "`` youain'tbitch '' favoritresponslongtext",
#  "`` youyoboypussicat . ''",
#  "`` youcunt ''",
#  "`` youpullpussidodgcollectpantialright . ''",
#  '-stormijak & # 128514 ; & # 128514 ; & # 128514 ;',
#  "`` youtakesomeonghetto , can'ttakeghetto . ''",
#  "`` youn'tlikeuscolorfolk , 'll'recolorwhitefuck '' & # 128514 ; & # 128514 ; & # 128514 ; & # 128514 ;",
#  "`` yougothellaho '' http : //t.co/zn1a0gstpc",
#  "`` youhitlight , linetocobell2morn , diana'sbackh .",
#  "it'smiracl '' -charli @ dianaaaxo",
#  "`` youlookcutetoday : ) '' ..",
#  "`` realli ? ! ''",
#  'helll , swervho !',
#  "`` youlooklikelittlbirdhelpgetdressmorn ''",
#  "`` youoltroutmouthassbitch '' deeeeaaaadd",
#  "`` youtalklikefagshit'sretard .",
#  "but'scoolscro , lot'stardlivetotalkick-assl ! ''",
#  '`` youtooklandcouldmakeretarddiap ?',
#  "sure .... useimag .... cool .... '' # redskin # nfl # concuss # joke",
#  "`` you'regardenros , bitchwe . ''",
#  "`` you'refuck '' noshitdumbasscuntgopostpicturflatasstittiigslut",
#  "`` yourqueer '' .",
#  '& # 128530 ; & # 128530 ; & # 128530 ; & # 128530 ;',
#  "`` yourhomeboylookbadgivecashho ''",
#  "`` yourteethlikestar . ''",
#  "`` awwthank ! ''",
#  "`` yeah ... yellowfaraway . ''",
#  '`` yup .',
#  "fuckem @ aloha_hoesss : playliketrashrt @ 80sbaby4lifclippern'twannaplaylol ''",
#  "`` ain'ttimehoeget '' lolariana'smomsayu",
#  "`` bitch ? ''",
#  '- @ chellyhernandez',
#  "`` ayoevenkillhandicapcripplbitches/lookscalprealclose'llseetriplsix ''",
#  "`` bitchfreakshit ''",
#  "`` bitchvaginalittlresili '' - @ rosestoko",
#  "`` ilov '' nahbitchain'tlov .",
#  "`` pussirootdramaattributputheadmama . ''",
#  "`` callkeyshawnjohnsoncausimcatchinerriho ''",
#  "`` captainsaveho '' annoyphras",
#  "`` dayjudgementeverybodigonnalookbigjumbotronwatchfuckmajjinnbuubitch ''",
#  "`` n'tletsidebitchsettl , imightheadbuttevelyn ''",
#  "`` dontshowbitchunlesslooklikedolliparton ! ! ! ''",
#  "`` fuckpussiasshatergosuckdickdiequick '' -someon , ,youtubcom .",
#  "ithink'dgoodfriend .",
#  "`` hickravervenndiagramlargintersect ''",
#  "`` hoesuckdickculooklikejohnstocktonhitemwitchoppa , lukefatherrr '' - @ lilbthebasedgod",
#  "`` wasntworkplaceiddeck '' ayefuckright , i'dgivetyson4combondenduppercut .",
#  'shutfuckbitch',
#  "`` suckdickdip , 'skeepertrueredneckwoman . ''",
#  "-kim'sdad .",
#  "`` imgonnaripbitchapart '' ''ripapart '' ''lol ''",
#  "`` britneybitch '' -bibl ( leviticu7:58 ) http : //t.co/zoakn1zlhm",
#  "`` niggabitchbitchassniggadikeasshoeblackassbrightasshoefagtagscalliwag ''",
#  "`` pussi , trynagostudio , n'tcallmufuckincriblik , god .",
#  'yo .',
#  "wordgodibussyoshit , god , word ''",
#  "`` ohyahoethinkcuteskintightcatsuitassumbodiboomindisput ''",
#  "`` omgbitchfuckstupidiswearblahblahblah '' * weeklat * omgilysmbaeurbestfriendiswear",
#  "`` wayfuckbitchnamethelord '' -mr.race",
#  "`` poorwhitey '' http : //t.co/3ukkeyznz8",
#  "`` ridebrostilln'ttrustho ''",
#  "`` weekendgofabul '' naaman , 'reseenaecunt .",
#  "if'llko2secondflat .",
#  'hateu .',
#  '# fuckgm',
#  "`` whatev , goodon . ''",
#  '-abrahamlincoln , quotyallho !',
#  "`` guysay `` latina & gt ; ''meankimkardashianlookgirlbitchshapelikeminifridg & amp ; smellliketortilla ''",
#  "`` rappersaytwatmakefeelweird '' & # 128514 ; & # 128514 ; & # 128514 ; & # 128557 ;",
#  "`` betterpipepussi '' - @ esex_ruskii & # 160 ; lmaowthevenmean ?",
#  "`` fuckpussicouldn'tevenbeatdick . ''",
#  '-angriyoutubcom',
#  "`` 'recuntright '' - @ rq978",
#  '# thatsonbitchmomentrainforgetcarwindow',
#  "# 10thingsthatgetsonmynervneediho , ratchetho , sidelinho , beggin'ho , dumbho , looklovefacebookho ..",
#  '# 11gethitbitchcampuw',
#  '# 1personidbitchslap @ khamruz .',
#  'fablowintl .',
#  'uplikebitchsparetireleavindairiqueen',
#  '# 2013favert & # 8220 ; @ grahamorama : # snoop # justinmuchfuncharliwilsontribut # betawardhttp : //t.co/c6nhwublxn & # 8221 ;',
#  '# 2013taughtmpussifeel & # 128514 ; & # 128076 ;',
#  '# 5wordsaftersexpussibitch ?',
#  "# azmonsoonlotrain , badn'tenoughwashawayteabaggracistwhitetrashst .",
#  '# tcot # teaparti # azflood',
#  ...]
